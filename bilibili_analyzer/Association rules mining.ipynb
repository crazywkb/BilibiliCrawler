# %%
import pyfpgrowth
import pandas as pd
import numpy as np
import json
import fp_growth_py3 as fpg
import matplotlib.pyplot as plt
import pylab as pl
from collections import defaultdict

# %% [markdown]
# ## 1. 数据预处理
# 从文件中读取数据集，对related_same_month_brand属性进行关联规则挖掘。
# 数据预处理主要是丢弃丢失值

# %%
def prefunction(x) :
    x = json.loads(x)
    if not x :
        return np.nan
    else :
        return x

converts = {
    "visitor_home_cbgs":prefunction,
    "visitor_work_cbgs":prefunction,
    "related_same_day_brand":prefunction,
    "related_same_month_brand":prefunction,
    "top_brands":prefunction,
    "popularity_by_hour":prefunction,
    "popularity_by_day":prefunction
}
    
data = pd.read_csv("cbg_patterns.csv",converters = converts)

dataSet = list(data["related_same_month_brand"].dropna())
dataSet
# Out:
# [['walmart',
#   'mcdonalds',
#   'Dollar General',
#   'Chick-fil-A',
#   'Marathon Petroleum',
#   'Shell Oil',
#   'Waffle House',
#   'SUBWAY',
#   'Publix Super Markets',
#   'Circle K Stores'],
#  ['walmart',
#   'mcdonalds',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Dollar General',
#   'SUBWAY',
#   'Chevron',
#   'Taco Bell',
#   'Cracker Barrel',
#   "Jack's Family Restaurants"],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Chevron',
#   'Shell Oil',
#   'Sonic',
#   'SUBWAY',
#   "Wendy's",
#   'Marathon Petroleum',
#   "Jack's Family Restaurants"],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Marathon Petroleum',
#   'Chick-fil-A',
#   'Waffle House',
#   'Sonic',
#   "Hardee's",
#   'Publix Super Markets',
#   "America's Thrift Store"],
#  ['walmart',
#   'Chevron',
#   'Dollar General',
#   'Shell Oil',
#   "Jack's Family Restaurants",
#   'mcdonalds',
#   'Chick-fil-A',
#   "America's Thrift Store",
#   'Taco Bell',
#   'SUBWAY'],
#  ['walmart',
#   'Shell Oil',
#   'Dollar General',
#   'mcdonalds',
#   'Chevron',
#   'Exxon Mobil',
#   'SUBWAY',
#   'Circle K Stores',
#   'Sonic',
#   'Chick-fil-A'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Chick-fil-A',
#   "Jack's Family Restaurants",
#   'Shell Oil',
#   'Burger King US',
#   'Chevron',
#   'SUBWAY',
#   "Arby's"],
#  ["Jack's Family Restaurants",
#   'walmart',
#   'Dollar General',
#   'Shell Oil',
#   'mcdonalds',
#   "America's Thrift Store",
#   'Chick-fil-A',
#   'Chevron',
#   'Waffle House',
#   'Sonic'],
#  ['starbucks',
#   'walmart',
#   'mcdonalds',
#   'Holiday Station',
#   'Costco Wholesale Corp.',
#   'Fred Meyer Jewelers',
#   'SUBWAY',
#   "Papa Murphy's",
#   'Carrs',
#   'Chevron'],
#  ['walmart',
#   'Chevron',
#   'Shell Oil',
#   "Denny's",
#   'mcdonalds',
#   'ConocoPhillips',
#   'Burger King US',
#   'SUBWAY',
#   'Circle K Stores',
#   'Ace Hardware'],
#  ['Circle K Stores',
#   'walmart',
#   'QuikTrip',
#   'mcdonalds',
#   "Fry's Food & Drug Stores",
#   'starbucks',
#   'Walgreens',
#   'Jack in the Box',
#   'SUBWAY',
#   'Taco Bell'],
#  ["Fry's Food & Drug Stores",
#   'Circle K Stores',
#   'starbucks',
#   'QuikTrip',
#   'mcdonalds',
#   'walmart',
#   'Costco Wholesale Corp.',
#   'Shell Oil',
#   'The Home Depot',
#   'Walgreens'],
#  ['Circle K Stores',
#   'QuikTrip',
#   "Fry's Food & Drug Stores",
#   'walmart',
#   'mcdonalds',
#   'Jack in the Box',
#   'starbucks',
#   'Walgreens',
#   'Chevron',
#   'Taco Bell'],
#  ['Circle K Stores',
#   "Fry's Food & Drug Stores",
#   'walmart',
#   'QuikTrip',
#   'mcdonalds',
#   'starbucks',
#   'Walgreens',
#   'Shell Oil',
#   'Jack in the Box',
#   'Costco Wholesale Corp.'],
#  ['Circle K Stores',
#   'walmart',
#   "Fry's Food & Drug Stores",
#   'QuikTrip',
#   'mcdonalds',
#   'Dollar Tree',
#   'Walgreens',
#   'Costco Wholesale Corp.',
#   'Shell Oil',
#   'Target'],
#  ['walmart',
#   'Circle K Stores',
#   'mcdonalds',
#   'Shell Oil',
#   'SUBWAY',
#   'starbucks',
#   "Fry's Food & Drug Stores",
#   'Pilot Travel Centers',
#   'QuikTrip',
#   'Walgreens'],
#  ['walmart',
#   'Circle K Stores',
#   'starbucks',
#   'Chevron',
#   'mcdonalds',
#   'Jack in the Box',
#   'SUBWAY',
#   'Shell Oil',
#   "Fry's Food & Drug Stores",
#   'Taco Bell'],
#  ['walmart',
#   'Sonic',
#   'mcdonalds',
#   'Dollar General',
#   'Valero Energy',
#   'Taco Bell',
#   'Murphy USA',
#   'Exxon Mobil',
#   'SUBWAY',
#   "fred's"],
#  ['walmart',
#   'Sonic',
#   'Dollar General',
#   'Valero Energy',
#   "Brookshire's Grocery Company",
#   'Exxon Mobil',
#   'Dollar Tree',
#   'Health Mart',
#   'Taco Bell',
#   'mcdonalds'],
#  ['walmart',
#   'Sonic',
#   'mcdonalds',
#   'Dollar General',
#   "Casey's General Stores",
#   'Taco Bell',
#   'Harps Food Store',
#   'Murphy USA',
#   "Braum's Ice Cream and Dairy Stores",
#   "Sam's Club"],
#  ['Sonic',
#   'walmart',
#   'Dollar General',
#   'Valero Energy',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Chick-fil-A'],
#  ['Costco Wholesale Corp.',
#   'Chevron',
#   'mcdonalds',
#   'starbucks',
#   'SUBWAY',
#   '7-Eleven US',
#   'Target',
#   'Jack in the Box',
#   '76',
#   'walmart'],
#  ['starbucks',
#   'Chevron',
#   'Safeway',
#   'Costco Wholesale Corp.',
#   'Shell Oil',
#   'Target',
#   'SUBWAY',
#   'In-N-Out Burger',
#   'mcdonalds',
#   'Jack in the Box'],
#  ['mcdonalds',
#   'walmart',
#   'SUBWAY',
#   'Chevron',
#   'starbucks',
#   'Taco Bell',
#   'ARCO',
#   'Shell Oil',
#   'Costco Wholesale Corp.',
#   'Jack in the Box'],
#  ['walmart',
#   'mcdonalds',
#   'Chevron',
#   'Jack in the Box',
#   'SUBWAY',
#   'Fastrip',
#   'Kmart',
#   'Taco Bell',
#   'starbucks',
#   "Denny's"],
#  ['starbucks',
#   'mcdonalds',
#   'In-N-Out Burger',
#   'Target',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'ARCO',
#   'SUBWAY',
#   'Ralphs',
#   'Jack in the Box'],
#  ['ARCO',
#   'starbucks',
#   'mcdonalds',
#   'Jack in the Box',
#   'In-N-Out Burger',
#   '7-Eleven US',
#   'Chevron',
#   'Target',
#   'walmart',
#   '99 Cents Only Stores'],
#  ['mcdonalds',
#   'ARCO',
#   'Jack in the Box',
#   '7-Eleven US',
#   'Chevron',
#   'starbucks',
#   'walmart',
#   'Food 4 Less',
#   '99 Cents Only Stores',
#   'Target'],
#  ['ARCO'],
#  ['starbucks',
#   'mcdonalds',
#   'In-N-Out Burger',
#   'walmart',
#   'Target',
#   'SUBWAY',
#   'Jack in the Box',
#   'ARCO',
#   'Shell Oil',
#   '7-Eleven US'],
#  ['starbucks',
#   'mcdonalds',
#   'Costco Wholesale Corp.',
#   'walmart',
#   'Dollar Tree',
#   '7-Eleven US',
#   'Chevron',
#   'Jack in the Box',
#   'Safeway',
#   'ARCO'],
#  ['starbucks',
#   'Target',
#   'mcdonalds',
#   'Chevron',
#   'ARCO',
#   'In-N-Out Burger',
#   'Costco Wholesale Corp.',
#   'Del Taco',
#   '7-Eleven US',
#   'Jack in the Box'],
#  ['ARCO',
#   'mcdonalds',
#   'starbucks',
#   'Jack in the Box',
#   'Chevron',
#   'walmart',
#   'SUBWAY',
#   'Del Taco',
#   'Target',
#   'In-N-Out Burger'],
#  ['starbucks',
#   'ARCO',
#   'Chevron',
#   'In-N-Out Burger',
#   'Target',
#   'Costco Wholesale Corp.',
#   'Jack in the Box',
#   'mcdonalds',
#   'walmart',
#   'Del Taco'],
#  ['walmart',
#   'ARCO',
#   'starbucks',
#   'Del Taco',
#   'Costco Wholesale Corp.',
#   'In-N-Out Burger',
#   'mcdonalds',
#   'Jack in the Box',
#   'Circle K Stores',
#   'TCBY'],
#  ['starbucks',
#   'ARCO',
#   'Chevron',
#   'mcdonalds',
#   'In-N-Out Burger',
#   'Target',
#   'Jack in the Box',
#   'Costco Wholesale Corp.',
#   'walmart',
#   'Del Taco'],
#  ['starbucks',
#   'ARCO',
#   'walmart',
#   'mcdonalds',
#   'Costco Wholesale Corp.',
#   'Jack in the Box',
#   'Del Taco',
#   'In-N-Out Burger',
#   'Chevron',
#   'Target'],
#  ['starbucks',
#   'Chevron',
#   'walmart',
#   'mcdonalds',
#   'ARCO',
#   'Costco Wholesale Corp.',
#   'Taco Bell',
#   'In-N-Out Burger',
#   'Target',
#   'Shell Oil'],
#  ['starbucks',
#   'mcdonalds',
#   'ARCO',
#   'Chevron',
#   'In-N-Out Burger',
#   'Target',
#   'Jack in the Box',
#   'SUBWAY',
#   'walmart',
#   '7-Eleven US'],
#  ['7-Eleven US',
#   'walmart',
#   'Jack in the Box',
#   'starbucks',
#   'ARCO',
#   'mcdonalds',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'SUBWAY',
#   '99 Cents Only Stores'],
#  ['starbucks',
#   'Costco Wholesale Corp.',
#   'In-N-Out Burger',
#   'Vons',
#   'Jack in the Box',
#   'ARCO',
#   '7-Eleven US',
#   'Target',
#   'mcdonalds',
#   'The Home Depot'],
#  ['starbucks',
#   'Costco Wholesale Corp.',
#   'Target',
#   'In-N-Out Burger',
#   'Chevron',
#   'walmart',
#   'Vons',
#   '7-Eleven US',
#   'mcdonalds',
#   'ARCO'],
#  ['Safeway',
#   'starbucks',
#   'Chevron',
#   'Costco Wholesale Corp.',
#   'Shell Oil',
#   'Target',
#   'Walgreens',
#   'In-N-Out Burger',
#   'mcdonalds',
#   'SUBWAY'],
#  ['Safeway',
#   'Costco Wholesale Corp.',
#   'starbucks',
#   'Chevron',
#   'Target',
#   'Walgreens',
#   'Shell Oil',
#   'In-N-Out Burger',
#   'SUBWAY',
#   "Trader Joe's"],
#  ['Chevron',
#   'mcdonalds',
#   'starbucks',
#   'walmart',
#   'Costco Wholesale Corp.',
#   'SUBWAY',
#   'Taco Bell',
#   'Jack in the Box',
#   'Target',
#   'ARCO'],
#  ['walmart',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'starbucks',
#   'mcdonalds',
#   'SUBWAY',
#   'Taco Bell',
#   'Target',
#   'In-N-Out Burger',
#   'Jack in the Box'],
#  ['starbucks',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'Safeway',
#   'Target',
#   'Shell Oil',
#   'Walgreens',
#   'mcdonalds',
#   'ARCO',
#   'In-N-Out Burger'],
#  ['Costco Wholesale Corp.',
#   'starbucks',
#   'Target',
#   'mcdonalds',
#   'Chevron',
#   'SUBWAY',
#   'Shell Oil',
#   '7-Eleven US',
#   'In-N-Out Burger',
#   'Jack in the Box'],
#  ['starbucks',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'Target',
#   'Safeway',
#   'In-N-Out Burger',
#   'mcdonalds',
#   'SUBWAY',
#   'Shell Oil',
#   '7-Eleven US'],
#  ['starbucks',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'Target',
#   'mcdonalds',
#   'Safeway',
#   'In-N-Out Burger',
#   'SUBWAY',
#   'Shell Oil',
#   '7-Eleven US'],
#  ['Costco Wholesale Corp.',
#   'starbucks',
#   'Chevron',
#   'Target',
#   'In-N-Out Burger',
#   'Michaels Stores',
#   'Safeway',
#   'mcdonalds',
#   '7-Eleven US',
#   'GameStop'],
#  ['starbucks',
#   'mcdonalds',
#   'Taco Bell',
#   'Chevron',
#   'Target',
#   'ARCO',
#   'Costco Wholesale Corp.',
#   'Dollar Tree',
#   'walmart',
#   'Save Mart Supermarkets'],
#  ['Chevron', 'Vons', 'In-N-Out Burger'],
#  ['starbucks',
#   'Target',
#   'Chevron',
#   'Costco Wholesale Corp.',
#   'In-N-Out Burger',
#   'ARCO',
#   'Goodwill Industries',
#   'Taco Bell',
#   'Safeway',
#   'mcdonalds'],
#  ['King Soopers',
#   'starbucks',
#   'Target',
#   'mcdonalds',
#   'Chick-fil-A',
#   'ConocoPhillips',
#   'Costco Wholesale Corp.',
#   'Walgreens',
#   'Chipotle Mexican Grill',
#   'Shell Oil'],
#  ['King Soopers',
#   'starbucks',
#   'walmart',
#   'mcdonalds',
#   'ConocoPhillips',
#   'Target',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Walgreens',
#   '7-Eleven US'],
#  ['King Soopers',
#   'walmart',
#   'starbucks',
#   'mcdonalds',
#   'ConocoPhillips',
#   '7-Eleven US',
#   'SUBWAY',
#   'Shell Oil',
#   "Wendy's",
#   'Target'],
#  ['walmart',
#   'starbucks',
#   'mcdonalds',
#   'ConocoPhillips',
#   'Kum & Go',
#   'King Soopers',
#   'Safeway',
#   '7-Eleven US',
#   'Walgreens',
#   'Taco Bell'],
#  ['walmart',
#   'starbucks',
#   'ConocoPhillips',
#   "Loaf 'N Jug",
#   'Kum & Go',
#   'mcdonalds',
#   '7-Eleven US',
#   'King Soopers',
#   'Safeway',
#   'Taco Bell'],
#  ["Dunkin' Donuts",
#   'CVS',
#   'Stop & Shop',
#   'Shell Oil',
#   'starbucks',
#   'Mobil',
#   'Costco Wholesale Corp.',
#   'Sunoco',
#   'mcdonalds',
#   'Whole Foods Market'],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'CVS',
#   'mcdonalds',
#   'Cumberland Farms',
#   'SUBWAY',
#   'starbucks',
#   'Mobil',
#   'T.J. Maxx',
#   'walmart'],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'mcdonalds',
#   'walmart',
#   'SUBWAY',
#   'CVS',
#   'Mobil',
#   'Shell Oil',
#   'Cumberland Farms',
#   'starbucks'],
#  ['starbucks',
#   'CVS',
#   'SUBWAY',
#   'mcdonalds',
#   '7-Eleven US',
#   'Giant Food Stores',
#   'Exxon Mobil',
#   'Chipotle Mexican Grill',
#   "Dunkin' Donuts",
#   'Safeway'],
#  ['walmart',
#   'mcdonalds',
#   'Dollar General',
#   'Publix Super Markets',
#   'Waffle House',
#   'Chick-fil-A',
#   'Chevron',
#   'Shell Oil',
#   'Exxon Mobil',
#   'Winn Dixie'],
#  ['Publix Super Markets',
#   'mcdonalds',
#   "Dunkin' Donuts",
#   'walmart',
#   'Walgreens',
#   'Mobil',
#   'Shell Oil',
#   'starbucks',
#   '7-Eleven US',
#   'CVS'],
#  ['Publix Super Markets',
#   'walmart',
#   "Dunkin' Donuts",
#   'mcdonalds',
#   'Dollar Tree',
#   'Walgreens',
#   '7-Eleven US',
#   'Mobil',
#   'Marathon Petroleum',
#   'Shell Oil'],
#  ['Publix Super Markets',
#   'Walgreens',
#   "Dunkin' Donuts",
#   'mcdonalds',
#   'CVS',
#   '7-Eleven US',
#   'walmart',
#   'Mobil',
#   'Chevron',
#   'The Home Depot'],
#  ['Navy Exchange',
#   'walmart',
#   'Publix Super Markets',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Whataburger',
#   'Tom Thumb',
#   'Circle K Stores',
#   'Waffle House',
#   'mcdonalds'],
#  ['walmart',
#   'Navy Exchange',
#   'Publix Super Markets',
#   'Shell Oil',
#   'Tom Thumb',
#   'mcdonalds',
#   'Whataburger',
#   'Chick-fil-A',
#   'Circle K Stores',
#   'CITGO Petroleum'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Shell Oil',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   'Marathon Petroleum',
#   'Publix Super Markets',
#   'CVS'],
#  ['walmart',
#   'mcdonalds',
#   'Publix Super Markets',
#   'Wawa',
#   '7-Eleven US',
#   'Shell Oil',
#   'Walgreens',
#   'Chick-fil-A',
#   'Circle K Stores',
#   'CVS'],
#  ['Publix Super Markets',
#   'mcdonalds',
#   'walmart',
#   '7-Eleven US',
#   'Shell Oil',
#   'RaceTrac',
#   'SUBWAY',
#   'Walgreens',
#   "Dunkin' Donuts",
#   'CVS'],
#  ['Publix Super Markets',
#   'walmart',
#   'mcdonalds',
#   '7-Eleven US',
#   'Wawa',
#   'Circle K Stores',
#   'Shell Oil',
#   'RaceTrac',
#   'Walgreens',
#   'Dollar General'],
#  ['Publix Super Markets',
#   'mcdonalds',
#   'Walgreens',
#   'CVS',
#   'walmart',
#   'Chevron',
#   'Shell Oil',
#   'Pollo Tropical',
#   'Burger King US',
#   'The Home Depot'],
#  ['Publix Super Markets',
#   'mcdonalds',
#   'Shell Oil',
#   'Walgreens',
#   'CVS',
#   'The Home Depot',
#   'walmart',
#   "Dunkin' Donuts",
#   'SUBWAY',
#   'starbucks'],
#  ['Publix Super Markets',
#   'walmart',
#   'mcdonalds',
#   '7-Eleven US',
#   'Walgreens',
#   'Shell Oil',
#   'Wawa',
#   'Chick-fil-A',
#   "Dunkin' Donuts",
#   'Circle K Stores'],
#  ['Publix Super Markets',
#   'walmart',
#   '7-Eleven US',
#   'Walgreens',
#   'mcdonalds',
#   'Wawa',
#   'Shell Oil',
#   'Dollar Tree',
#   "Dunkin' Donuts",
#   'CVS'],
#  ['Publix Super Markets',
#   'walmart',
#   'mcdonalds',
#   '7-Eleven US',
#   'Walgreens',
#   'Shell Oil',
#   'Wawa',
#   "Dunkin' Donuts",
#   'Chick-fil-A',
#   'CVS'],
#  ['Publix Super Markets',
#   'Wawa',
#   'mcdonalds',
#   '7-Eleven US',
#   'Chick-fil-A',
#   'walmart',
#   'Target',
#   'Walgreens',
#   'starbucks',
#   'RaceTrac'],
#  ['walmart',
#   'Circle K Stores',
#   'Dollar General',
#   'Chick-fil-A',
#   'mcdonalds',
#   "Zaxby's",
#   'Shell Oil',
#   'BP',
#   "Wendy's",
#   "Hardee's"],
#  ['walmart',
#   'mcdonalds',
#   'Chick-fil-A',
#   'QuikTrip',
#   'Shell Oil',
#   "Wendy's",
#   'BP',
#   'Chevron',
#   'Waffle House',
#   'SUBWAY'],
#  ['Chevron',
#   'walmart',
#   'Shell Oil',
#   'mcdonalds',
#   'QuikTrip',
#   'Kroger',
#   'Family Dollar Stores',
#   'BP',
#   'Chick-fil-A',
#   "Wendy's"],
#  ['QuikTrip',
#   'Chick-fil-A',
#   'walmart',
#   'mcdonalds',
#   'starbucks',
#   'Kroger',
#   'RaceTrac',
#   'Shell Oil',
#   'Waffle House',
#   'Chevron'],
#  ['Chick-fil-A',
#   'QuikTrip',
#   'walmart',
#   'mcdonalds',
#   'starbucks',
#   'Chevron',
#   'Kroger',
#   'Publix Super Markets',
#   "Wendy's",
#   'Waffle House'],
#  ['walmart',
#   'QuikTrip',
#   'Chick-fil-A',
#   'mcdonalds',
#   'Chevron',
#   'Shell Oil',
#   'RaceTrac',
#   'Waffle House',
#   "Wendy's",
#   'Kroger'],
#  ['Chick-fil-A',
#   'walmart',
#   'mcdonalds',
#   'QuikTrip',
#   'starbucks',
#   "Wendy's",
#   'RaceTrac',
#   'Waffle House',
#   "Zaxby's",
#   'Chevron'],
#  ['walmart',
#   'Chick-fil-A',
#   'mcdonalds',
#   'QuikTrip',
#   'Waffle House',
#   'BP',
#   "Wendy's",
#   'Chevron',
#   'Publix Super Markets',
#   'Dollar General'],
#  ['Circle K Stores',
#   'walmart',
#   'Dollar General',
#   'Chick-fil-A',
#   'CITGO Petroleum',
#   'mcdonalds',
#   'Dairy Queen',
#   "Zaxby's",
#   "Wendy's",
#   'PetSmart'],
#  ['walmart',
#   'Chick-fil-A',
#   'mcdonalds',
#   'Kroger',
#   "Zaxby's",
#   'Dollar General',
#   'Dairy Queen',
#   'Waffle House',
#   'BP',
#   'Chevron'],
#  ['walmart',
#   'mcdonalds',
#   'Circle K Stores',
#   'Shell Oil',
#   'Chick-fil-A',
#   'starbucks',
#   'Waffle House',
#   'SUBWAY',
#   'Dollar General',
#   'Family Dollar Stores'],
#  ['Target',
#   'walmart',
#   'CVS',
#   'mcdonalds',
#   'Good Neighbor Pharmacy',
#   'Pizza Hut',
#   'starbucks',
#   'Costco Wholesale Corp.',
#   'The Home Depot',
#   'Shell Oil'],
#  ['ConocoPhillips',
#   'walmart',
#   'Exxon Mobil',
#   'Safeway',
#   'Costco Wholesale Corp.',
#   'The Home Depot',
#   'Ace Hardware',
#   'Chevron',
#   'Good Neighbor Pharmacy',
#   'United States Postal Service (USPS)'],
#  ['starbucks',
#   "Dunkin' Donuts",
#   'mcdonalds',
#   'Walgreens',
#   'Target',
#   'Jewel-Osco',
#   'BP',
#   'SUBWAY',
#   'Shell Oil',
#   'Potbelly Sandwich Works'],
#  ['mcdonalds',
#   'Walgreens',
#   "Dunkin' Donuts",
#   'starbucks',
#   'Jewel-Osco',
#   'BP',
#   'Target',
#   'SUBWAY',
#   'Shell Oil',
#   '7-Eleven US'],
#  ['mcdonalds',
#   'Walgreens',
#   "Dunkin' Donuts",
#   'walmart',
#   'BP',
#   'Dollar Tree',
#   'Jewel-Osco',
#   'SUBWAY',
#   'Target',
#   'Shell Oil'],
#  ['mcdonalds',
#   'starbucks',
#   'Walgreens',
#   'Jewel-Osco',
#   'Target',
#   'walmart',
#   'Shell Oil',
#   'Costco Wholesale Corp.',
#   "Dunkin' Donuts",
#   'BP'],
#  ['mcdonalds',
#   'Walgreens',
#   "Dunkin' Donuts",
#   'walmart',
#   'BP',
#   'Shell Oil',
#   'Target',
#   'Jewel-Osco',
#   'SUBWAY',
#   'Dollar Tree'],
#  ['mcdonalds',
#   'Walgreens',
#   'starbucks',
#   'Target',
#   "Dunkin' Donuts",
#   'walmart',
#   'Jewel-Osco',
#   'BP',
#   "Portillo's Restaurants",
#   'Shell Oil'],
#  ['Jewel-Osco',
#   'mcdonalds',
#   'Walgreens',
#   'starbucks',
#   'Target',
#   'walmart',
#   "Dunkin' Donuts",
#   'Shell Oil',
#   'Speedway',
#   "Portillo's Restaurants"],
#  ["Casey's General Stores",
#   'BP',
#   'walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Hy-Vee',
#   "Menard's",
#   'Phillips 66',
#   'Dairy Queen',
#   "Culver's"],
#  ['starbucks',
#   'Walgreens',
#   'mcdonalds',
#   'Target',
#   "Dunkin' Donuts",
#   'Jewel-Osco',
#   'BP',
#   'Shell Oil',
#   "Mariano's",
#   'Costco Wholesale Corp.'],
#  ['walmart',
#   "Casey's General Stores",
#   'mcdonalds',
#   'Dollar General',
#   'Dairy Queen',
#   'Phillips 66',
#   'SUBWAY',
#   'Shell Oil',
#   "Hardee's",
#   'Taco Bell'],
#  ['mcdonalds',
#   'Mobil',
#   'walmart',
#   'Walgreens',
#   "Culver's",
#   'SUBWAY',
#   "Menard's",
#   'Taco Bell',
#   'Target',
#   'Schnucks'],
#  ['walmart',
#   'mcdonalds',
#   'Speedway',
#   'Dollar General',
#   'Kroger',
#   "Wendy's",
#   'BP',
#   'CVS',
#   'Marathon Petroleum',
#   'Rural King'],
#  ['walmart',
#   'mcdonalds',
#   'Goodwill Industries',
#   'Dollar General',
#   'Marathon Petroleum',
#   'BP',
#   'Speedway',
#   'Taco Bell',
#   'Burger King US',
#   'Dairy Queen'],
#  ['mcdonalds',
#   'Kroger',
#   'starbucks',
#   'Speedway',
#   'walmart',
#   'CVS',
#   'Meijer',
#   'Target',
#   "Steak 'n Shake",
#   'Chick-fil-A'],
#  ['Speedway',
#   'walmart',
#   'mcdonalds',
#   'Kroger',
#   'Marathon Petroleum',
#   'CVS',
#   'Meijer',
#   'BP',
#   'Dollar General',
#   "Steak 'n Shake"],
#  ['mcdonalds',
#   'Meijer',
#   'walmart',
#   'Speedway',
#   'Marathon Petroleum',
#   'Phillips 66',
#   'Taco Bell',
#   'Burger King US',
#   'Goodwill Industries',
#   'SUBWAY'],
#  ["Casey's General Stores",
#   'walmart',
#   'mcdonalds',
#   'Kwik Trip',
#   'SUBWAY',
#   'Hy-Vee',
#   'BP',
#   'Pilot Travel Centers',
#   "Menard's",
#   'Fareway Stores'],
#  ["Casey's General Stores",
#   'walmart',
#   'mcdonalds',
#   'SUBWAY',
#   'Dollar General',
#   "Menard's",
#   'BP',
#   "Culver's",
#   'Hy-Vee',
#   'Fareway Stores'],
#  ['Hy-Vee',
#   "Casey's General Stores",
#   'Kum & Go',
#   'walmart',
#   'mcdonalds',
#   'BP',
#   'Walgreens',
#   'SUBWAY',
#   "Menard's",
#   'Pancheros'],
#  ["Casey's General Stores",
#   'Dollar General',
#   'walmart',
#   'Hy-Vee',
#   'SUBWAY',
#   'mcdonalds',
#   "Menard's",
#   'Fareway Stores',
#   'Good Neighbor Pharmacy',
#   "Hardee's"],
#  ["Casey's General Stores",
#   'Hy-Vee',
#   'Kum & Go',
#   'QuikTrip',
#   'walmart',
#   'mcdonalds',
#   'Walgreens',
#   'Fareway Stores',
#   'SUBWAY',
#   'starbucks'],
#  ["Casey's General Stores",
#   'walmart',
#   'Hy-Vee',
#   'mcdonalds',
#   'Kum & Go',
#   'Fareway Stores',
#   'SUBWAY',
#   'Target',
#   "Menard's",
#   "Culver's"],
#  ['Dillons Supermarkets', "Casey's General Stores", 'ConocoPhillips', 'Sonic'],
#  ['walmart',
#   "Casey's General Stores",
#   'Sonic',
#   'mcdonalds',
#   'Kwik Shop',
#   'Dillons Supermarkets',
#   'Dollar General',
#   'Pizza Hut',
#   'SUBWAY',
#   'Dairy Queen'],
#  ['walmart',
#   'mcdonalds',
#   'Speedway',
#   "Wendy's",
#   'Dollar General',
#   'Taco Bell',
#   'Kroger',
#   'Dollar Tree',
#   'Family Dollar Stores',
#   'Marathon Petroleum'],
#  ['walmart',
#   'Dollar General',
#   'Marathon Petroleum',
#   'mcdonalds',
#   'Dairy Queen',
#   'Shell Oil',
#   "Hardee's",
#   'SUBWAY',
#   'Dollar Tree',
#   'Walgreens'],
#  ['Marathon Petroleum', 'Kroger'],
#  ['Sonic',
#   'walmart',
#   'Dollar General',
#   'Chevron',
#   'mcdonalds',
#   'Exxon Mobil',
#   'Walgreens',
#   'Popeyes Louisiana Kitchen',
#   'Shell Oil',
#   "Wendy's"],
#  ['walmart',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Shell Oil',
#   'Circle K Stores',
#   'Sonic',
#   'Dollar General',
#   'SUBWAY',
#   'Family Dollar Stores',
#   'Chevron'],
#  ['walmart',
#   'Walgreens',
#   'mcdonalds',
#   'Family Dollar Stores',
#   'Shell Oil',
#   'Exxon Mobil',
#   "Wendy's",
#   'Popeyes Louisiana Kitchen',
#   'Cricket Wireless',
#   'Dollar General'],
#  ['walmart',
#   'Dollar General',
#   'Chevron',
#   'mcdonalds',
#   'Family Dollar Stores',
#   'Exxon Mobil',
#   'Sonic',
#   'Shell Oil',
#   'RaceTrac',
#   'Good Neighbor Pharmacy'],
#  ['Hannaford Supermarkets',
#   "Dunkin' Donuts",
#   'Irving Oil',
#   'walmart',
#   'mcdonalds',
#   'CITGO Petroleum',
#   'Dollar Tree',
#   'Dollar General',
#   'Circle K Stores',
#   'Sunoco'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'walmart',
#   'starbucks',
#   'CVS',
#   'Hannaford Supermarkets',
#   'SUBWAY',
#   'Shell Oil',
#   'Cumberland Farms',
#   'Target'],
#  ['Hannaford Supermarkets',
#   "Dunkin' Donuts",
#   'Cumberland Farms',
#   'walmart',
#   'Irving Oil',
#   'mcdonalds',
#   'Rite Aid',
#   'CITGO Petroleum',
#   'SUBWAY',
#   'Market Basket'],
#  ['Royal Farms',
#   'mcdonalds',
#   'Chick-fil-A',
#   '7-Eleven US',
#   "Dunkin' Donuts",
#   'walmart',
#   'Rite Aid',
#   'CVS',
#   'Shell Oil',
#   'Exxon Mobil'],
#  ['Royal Farms',
#   'mcdonalds',
#   'Chick-fil-A',
#   '7-Eleven US',
#   'walmart',
#   "Dunkin' Donuts",
#   'SUBWAY',
#   'Wawa',
#   'Giant Food Stores',
#   'Target'],
#  ['starbucks',
#   'mcdonalds',
#   '7-Eleven US',
#   'Giant Food Stores',
#   'SUBWAY',
#   'CVS',
#   'Exxon Mobil',
#   'Tesla Motors',
#   'Shell Oil',
#   'Sunoco'],
#  ['7-Eleven US',
#   'mcdonalds',
#   'Wawa',
#   'starbucks',
#   'Shell Oil',
#   'CVS',
#   'Giant Food Stores',
#   'SUBWAY',
#   'walmart',
#   'Chick-fil-A'],
#  ['7-Eleven US',
#   'mcdonalds',
#   'starbucks',
#   'Shell Oil',
#   'CVS',
#   'SUBWAY',
#   'Exxon Mobil',
#   'Giant Food Stores',
#   "Wendy's",
#   "Dunkin' Donuts"],
#  ['Royal Farms',
#   'walmart',
#   'mcdonalds',
#   'Wawa',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   "Dunkin' Donuts",
#   '7-Eleven US',
#   'Food Lion',
#   'Dollar General'],
#  ['Royal Farms',
#   'Wawa',
#   "Lowe's",
#   'mcdonalds',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   'Target',
#   'SUBWAY',
#   'starbucks',
#   'United States Postal Service (USPS)'],
#  ["Dunkin' Donuts",
#   'CVS',
#   'Cumberland Farms',
#   'Stop & Shop',
#   'mcdonalds',
#   'walmart',
#   'Target',
#   'Mobil',
#   "Wendy's",
#   'The Home Depot'],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'Market Basket',
#   'CVS',
#   'Whole Foods Market',
#   'starbucks',
#   'mcdonalds',
#   'Mobil',
#   'The Home Depot',
#   'Target'],
#  ["Dunkin' Donuts",
#   'CVS',
#   'mcdonalds',
#   'walmart',
#   'Stop & Shop',
#   'Cumberland Farms',
#   'SUBWAY',
#   'Sunoco',
#   'Dollar Tree',
#   'Big Y Foods'],
#  ["Dunkin' Donuts",
#   'Cumberland Farms',
#   'Stop & Shop',
#   'mcdonalds',
#   'CVS',
#   'walmart',
#   'Big Y Foods',
#   'Mobil',
#   'The Home Depot',
#   'Sunoco'],
#  ["Dunkin' Donuts",
#   'Market Basket',
#   'CVS',
#   'mcdonalds',
#   'Olympia Sports',
#   'Hannaford Supermarkets',
#   'Mobil',
#   'National Association for the Education of Young Children (NAEYC)',
#   'Hallmark Cards',
#   'Cumberland Farms'],
#  ["Dunkin' Donuts", 'Market Basket', 'Mobil'],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'Market Basket',
#   'CVS',
#   'mcdonalds',
#   'Target',
#   'Mobil',
#   'starbucks',
#   'Dollar Tree',
#   'Walgreens'],
#  ["Dunkin' Donuts",
#   'CVS',
#   'Market Basket',
#   'Mobil',
#   'starbucks',
#   'Cumberland Farms',
#   'mcdonalds',
#   'Stop & Shop',
#   'T.J. Maxx',
#   'Anytime Fitness'],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'CVS',
#   "BJ's Wholesale Club",
#   'starbucks',
#   'National Association for the Education of Young Children (NAEYC)',
#   "BJ's Optical",
#   'T.J. Maxx',
#   'mcdonalds',
#   '7-Eleven US'],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'CVS',
#   'mcdonalds',
#   'Cumberland Farms',
#   'Target',
#   'T.J. Maxx',
#   "BJ's Wholesale Club",
#   'The Home Depot',
#   "Wendy's"],
#  ["Dunkin' Donuts",
#   'Stop & Shop',
#   'walmart',
#   'CVS',
#   'Cumberland Farms',
#   'Market Basket',
#   'mcdonalds',
#   "Wendy's",
#   'Target',
#   'Dollar Tree'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'CVS',
#   'starbucks',
#   'SUBWAY',
#   'Mobil',
#   'Stop & Shop',
#   'walmart',
#   'Shell Oil',
#   'Cumberland Farms'],
#  ['Shopko', 'BP', 'Holiday Station', 'walmart', 'Auto Wares', 'Shell Oil'],
#  ['Meijer',
#   'Speedway',
#   'mcdonalds',
#   'Family Dollar Stores',
#   'Kroger',
#   'SUBWAY',
#   'Auto Wares',
#   'BIGGBY COFFEE',
#   'Dollar General',
#   "Wendy's"],
#  ['Kroger',
#   'Meijer',
#   'mcdonalds',
#   'Tim Hortons',
#   'Target',
#   'Speedway',
#   'CVS',
#   'starbucks',
#   'Mobil',
#   'walmart'],
#  ['mcdonalds',
#   'Kroger',
#   'Meijer',
#   'BP',
#   'Mobil',
#   'CVS',
#   'Marathon Petroleum',
#   'SUBWAY',
#   'Speedway',
#   'Tim Hortons'],
#  ['mcdonalds',
#   'Meijer',
#   'Marathon Petroleum',
#   'Tim Hortons',
#   'BP',
#   'SUBWAY',
#   'Kroger',
#   'walmart',
#   'Taco Bell',
#   'CVS'],
#  ['mcdonalds',
#   'Kroger',
#   'Meijer',
#   'BP',
#   'Mobil',
#   'Marathon Petroleum',
#   'CVS',
#   'SUBWAY',
#   'Tim Hortons',
#   'Speedway'],
#  ['mcdonalds',
#   'BP',
#   'Mobil',
#   'Marathon Petroleum',
#   'Meijer',
#   'Kroger',
#   'CVS',
#   'SUBWAY',
#   'Family Dollar Stores',
#   'Health Mart'],
#  ['Kroger',
#   'mcdonalds',
#   'CVS',
#   'Target',
#   'Costco Wholesale Corp.',
#   'Speedway',
#   'The Home Depot',
#   'Tim Hortons',
#   'starbucks',
#   'Meijer'],
#  ['Holiday Station',
#   'Kwik Trip',
#   'walmart',
#   "Menard's",
#   'Caribou Coffee',
#   'Target',
#   'mcdonalds',
#   'SuperAmerica',
#   'Dairy Queen',
#   'Mills Fleet Farm'],
#  ['Hy-Vee',
#   "Casey's General Stores",
#   'Shopko',
#   'mcdonalds',
#   'Minnesota DMV',
#   'Do It Best',
#   'SuperAmerica',
#   'walmart',
#   'Kwik Trip',
#   'Dairy Queen'],
#  ['Kwik Trip',
#   'SUBWAY',
#   "Menard's",
#   'walmart',
#   'Mills Fleet Farm',
#   'mcdonalds',
#   'BP',
#   'Target',
#   "Casey's General Stores",
#   "Culver's"],
#  ['Holiday Station',
#   'Target',
#   'Caribou Coffee',
#   'mcdonalds',
#   'Cub Foods',
#   'SuperAmerica',
#   'Kwik Trip',
#   'walmart',
#   'SUBWAY',
#   'Walgreens'],
#  ['Holiday Station',
#   'Target',
#   'Caribou Coffee',
#   'SuperAmerica',
#   'mcdonalds',
#   'SUBWAY',
#   'Cub Foods',
#   'Kwik Trip',
#   "Menard's",
#   'Walgreens'],
#  ['United States Postal Service (USPS)',
#   'Dairy Queen',
#   'Hardware Hank',
#   'The American Legion',
#   'mcdonalds',
#   'Holiday Station',
#   'Maytag',
#   "Menard's",
#   'Tesoro',
#   'walmart'],
#  ['Holiday Station',
#   "Coborn's",
#   'Mills Fleet Farm',
#   'Kwik Trip',
#   "Casey's General Stores"],
#  ['walmart',
#   'mcdonalds',
#   'Sonic',
#   "Wendy's",
#   'Dollar General',
#   "fred's",
#   'Family Dollar Stores',
#   'Shell Oil',
#   'Exxon Mobil',
#   'Taco Bell'],
#  ['walmart',
#   'mcdonalds',
#   "Casey's General Stores",
#   'Phillips 66',
#   'SUBWAY',
#   'Dollar General',
#   'ConocoPhillips',
#   'Goodwill Industries',
#   'Mobil',
#   'Taco Bell'],
#  ['QuikTrip',
#   'mcdonalds',
#   'walmart',
#   'Phillips 66',
#   'Sonic',
#   'Price Chopper',
#   'SUBWAY',
#   'Taco Bell',
#   'Walgreens',
#   "Casey's General Stores"],
#  ['Phillips 66',
#   'walmart',
#   'mcdonalds',
#   'QuikTrip',
#   'Walgreens',
#   'Burger King US',
#   'Taco Bell',
#   'Dollar General',
#   'Dairy Queen',
#   'BP'],
#  ['walmart',
#   'mcdonalds',
#   "Casey's General Stores",
#   'Dollar General',
#   'Phillips 66',
#   'Sonic',
#   "Menard's",
#   'SUBWAY',
#   'Hy-Vee',
#   'Taco Bell'],
#  ["Casey's General Stores",
#   'walmart',
#   'mcdonalds',
#   'Dollar General',
#   'SUBWAY',
#   'Hy-Vee',
#   'Sonic',
#   'Chick-fil-A',
#   'QuikTrip',
#   'Taco Bell'],
#  ['Schnucks',
#   'mcdonalds',
#   'QuikTrip',
#   'Walgreens',
#   'Phillips 66',
#   'walmart',
#   'Target',
#   'Chick-fil-A',
#   'starbucks',
#   'Dierbergs Markets'],
#  ['mcdonalds',
#   'walmart',
#   'Phillips 66',
#   'QuikTrip',
#   'Walgreens',
#   'Schnucks',
#   'Taco Bell',
#   'BP',
#   'Dollar Tree',
#   "Steak 'n Shake"],
#  ['QuikTrip',
#   'Family Dollar Stores',
#   'Schnucks',
#   'Phillips 66',
#   'BP',
#   'mcdonalds',
#   'Mobil',
#   'Walgreens',
#   'White Castle',
#   'walmart'],
#  ['SmartStyle Family Hair Salons',
#   'ConocoPhillips',
#   'mcdonalds',
#   'Albertsons Market',
#   'walmart',
#   'Holiday Station',
#   'starbucks',
#   "Sam's Club",
#   'TownPump Convenience Stores',
#   'Exxon Mobil'],
#  ['TownPump Convenience Stores',
#   'ConocoPhillips',
#   'Exxon Mobil',
#   'Associated Food Stores',
#   'Hardware Hank',
#   'CARQUEST Auto Parts',
#   'SUBWAY',
#   'IGA (Independent Grocers Alliance)',
#   'Ace Hardware',
#   'Dairy Queen'],
#  ['Sinclair Oil',
#   "Casey's General Stores",
#   'mcdonalds',
#   'United States Postal Service (USPS)',
#   'SUBWAY',
#   'walmart',
#   'Shopko',
#   'Runza',
#   'Dollar General',
#   'Dairy Queen'],
#  ['Hy-Vee',
#   'walmart',
#   'mcdonalds',
#   'Kum & Go',
#   'Walgreens',
#   'Kwik Shop',
#   'Phillips 66',
#   'Taco Bell',
#   'BP',
#   'QuikTrip'],
#  ['Hy-Vee',
#   'walmart',
#   "Casey's General Stores",
#   'Phillips 66',
#   'mcdonalds',
#   'Runza',
#   'Walgreens',
#   'Target',
#   'National Association for the Education of Young Children (NAEYC)',
#   'Amigos/Kings Classic'],
#  ['walmart',
#   "Casey's General Stores",
#   'SUBWAY',
#   'mcdonalds',
#   "Love's Travel Stops and Country Stores",
#   'Pilot Travel Centers',
#   'Phillips 66',
#   'Sinclair Oil',
#   'Shell Oil',
#   'Dollar General'],
#  ["Dunkin' Donuts",
#   'Market Basket',
#   'Hannaford Supermarkets',
#   'mcdonalds',
#   'Mobil',
#   'walmart',
#   'CVS',
#   'The Home Depot',
#   'Hallmark Cards',
#   'Rite Aid'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'ShopRite',
#   'Hallmark Cards',
#   'Tesla Motors',
#   'Target',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Burger King US',
#   'CVS'],
#  ["Dunkin' Donuts",
#   'ShopRite',
#   'Tesla Motors',
#   'CVS',
#   'starbucks',
#   'Urban Edge Properties',
#   'Dollar Tree',
#   'Stop & Shop',
#   'Exxon Mobil',
#   'The Home Depot'],
#  ["Dunkin' Donuts",
#   'Burger King US',
#   'Exxon Mobil',
#   'Hallmark Cards',
#   'Target',
#   'mcdonalds',
#   '7-Eleven US',
#   'BP',
#   'ShopRite',
#   'walmart'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   "Wendy's",
#   'ShopRite',
#   'Tesla Motors',
#   'Stop & Shop',
#   'CVS',
#   '7-Eleven US',
#   'T.J. Maxx',
#   'Exxon Mobil'],
#  ['Wawa',
#   "Dunkin' Donuts",
#   'mcdonalds',
#   'CVS',
#   'walmart',
#   'ShopRite',
#   'Chick-fil-A',
#   'Dollar Tree',
#   'Rite Aid',
#   "Wendy's"],
#  ['Wawa',
#   'ShopRite',
#   "Dunkin' Donuts",
#   'walmart',
#   'The Home Depot',
#   'Pet Valu',
#   'CVS',
#   'mcdonalds',
#   'Costco Wholesale Corp.',
#   'Exxon Mobil'],
#  ["Dunkin' Donuts",
#   'Wawa',
#   'ShopRite',
#   'CVS',
#   'mcdonalds',
#   '7-Eleven US',
#   'Dollar General',
#   'Panera Bread',
#   'walmart',
#   'starbucks'],
#  ["Dunkin' Donuts",
#   'Wawa',
#   'Costco Wholesale Corp.',
#   'mcdonalds',
#   'ShopRite',
#   'Staples',
#   'Target',
#   'CVS',
#   'Stop & Shop',
#   'Dollar Tree'],
#  ['Wawa',
#   'ShopRite',
#   "Dunkin' Donuts",
#   'walmart',
#   'Dollar Tree',
#   'mcdonalds',
#   '7-Eleven US',
#   'CVS',
#   'Walgreens',
#   "Wendy's"],
#  ["Dunkin' Donuts",
#   'ShopRite',
#   'starbucks',
#   'Stop & Shop',
#   'CVS',
#   'T.J. Maxx',
#   'Pet Valu',
#   "Wendy's",
#   'mcdonalds',
#   'Staples'],
#  ["Dunkin' Donuts",
#   'ShopRite',
#   'Stop & Shop',
#   '7-Eleven US',
#   'Walgreens',
#   'mcdonalds',
#   'Costco Wholesale Corp.',
#   'CVS',
#   'The Home Depot',
#   'Target'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'Sunoco',
#   'Weis Markets',
#   'walmart',
#   'CVS',
#   'Wegmans Food Markets',
#   'Urban Edge Properties',
#   'SUBWAY',
#   'Price Chopper'],
#  ['mcdonalds',
#   'walmart',
#   'SUBWAY',
#   'Pilot Travel Centers',
#   'Sunoco',
#   'Burger King US',
#   "Wendy's",
#   "Love's Travel Stops and Country Stores",
#   "Dunkin' Donuts",
#   'TravelCenters of America'],
#  ['Tim Hortons',
#   'walmart',
#   'Dollar General',
#   'Wegmans Food Markets',
#   'mcdonalds',
#   'Kwik Fill',
#   'Dollar Tree',
#   'Tops Friendly Markets',
#   'Burger King US',
#   'The Home Depot'],
#  ["Dunkin' Donuts",
#   'Mobil',
#   'Stop & Shop',
#   'mcdonalds',
#   'Target',
#   'Sunoco',
#   "Stewart's Shops",
#   'Rite Aid',
#   'The Home Depot',
#   'CVS'],
#  ['Tim Hortons',
#   'Wegmans Food Markets',
#   'Tops Friendly Markets',
#   'Sunoco',
#   'mcdonalds',
#   'Dollar General',
#   'walmart',
#   'Rite Aid',
#   'Dollar Tree',
#   '7-Eleven US'],
#  ["Dunkin' Donuts",
#   "Stewart's Shops",
#   'mcdonalds',
#   'Hannaford Supermarkets',
#   'Sunoco',
#   'walmart',
#   'Cumberland Farms',
#   'Mobil',
#   'CVS',
#   'The Home Depot'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'mcdonalds',
#   'BP',
#   'Rite Aid',
#   'SUBWAY',
#   'Burger King US',
#   'Baskin Robbins',
#   '7-Eleven US',
#   'Mobil'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'BP',
#   'mcdonalds',
#   'Rite Aid',
#   'Burger King US',
#   'Baskin Robbins',
#   '7-Eleven US',
#   'SUBWAY',
#   'CVS'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'BP',
#   'mcdonalds',
#   'SUBWAY',
#   'Baskin Robbins',
#   'Rite Aid',
#   'Chipotle Mexican Grill',
#   '7-Eleven US',
#   'CVS'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'BP',
#   'Dollar Tree',
#   'Popeyes Louisiana Kitchen',
#   'Family Dollar Stores',
#   'Burger King US',
#   'Baskin Robbins',
#   'Rite Aid',
#   "BJ's Wholesale Club"],
#  ['Wegmans Food Markets',
#   "Dunkin' Donuts",
#   'Sunoco',
#   'mcdonalds',
#   "BJ's Wholesale Club",
#   'Hallmark Cards',
#   'Tim Hortons',
#   "BJ's Optical",
#   'Dollar Tree',
#   'Mobil'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'BP',
#   'Stop & Shop',
#   '7-Eleven US',
#   'CVS',
#   'Baskin Robbins',
#   'Target',
#   'SUBWAY',
#   'Rite Aid'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'BP',
#   'walmart',
#   "BJ's Wholesale Club",
#   'CVS',
#   'The Home Depot',
#   'Burger King US',
#   '7-Eleven US',
#   "BJ's Optical"],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'BP',
#   '7-Eleven US',
#   'Baskin Robbins',
#   'CVS',
#   'Mobil',
#   'Stop & Shop',
#   'Dollar Tree',
#   'Petland Discounts'],
#  ["Dunkin' Donuts",
#   '7-Eleven US',
#   'starbucks',
#   'CVS',
#   'Stop & Shop',
#   'mcdonalds',
#   'ShopRite',
#   'Baskin Robbins',
#   'Target',
#   'Speedway'],
#  ["Dunkin' Donuts",
#   'walmart',
#   'Sunoco',
#   'mcdonalds',
#   'Big Lots Stores',
#   'Spirit Halloween',
#   "Stewart's Shops",
#   'Rite Aid',
#   'Dollar General',
#   'Dollar Tree'],
#  ["Dunkin' Donuts",
#   'Wegmans Food Markets',
#   'Sunoco',
#   'mcdonalds',
#   'Kinney Drugs',
#   'Circle K Stores',
#   'Rite Aid',
#   'Dollar Tree',
#   'walmart',
#   'Target'],
#  ['Wegmans Food Markets',
#   "Dunkin' Donuts",
#   'Sunoco',
#   'Kinney Drugs',
#   'Tops Friendly Markets',
#   'Rite Aid',
#   'Target',
#   'ALDI',
#   'mcdonalds',
#   "Stewart's Shops"],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'mcdonalds',
#   'SUBWAY',
#   'BP',
#   'Baskin Robbins',
#   'Rite Aid',
#   'Burger King US',
#   '7-Eleven US',
#   'CVS'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'BP',
#   'starbucks',
#   'SUBWAY',
#   'Rite Aid',
#   'Baskin Robbins',
#   'Popeyes Louisiana Kitchen',
#   'Burger King US',
#   'Mobil'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'mcdonalds',
#   'BP',
#   'SUBWAY',
#   'Baskin Robbins',
#   'The Home Depot',
#   'Rite Aid',
#   'Burger King US',
#   "BJ's Wholesale Club"],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'Stop & Shop',
#   'Rite Aid',
#   'starbucks',
#   '7-Eleven US',
#   'BP',
#   'Baskin Robbins',
#   'CVS',
#   'SUBWAY'],
#  ["Dunkin' Donuts",
#   'starbucks',
#   'mcdonalds',
#   'CVS',
#   'BP',
#   '7-Eleven US',
#   'Stop & Shop',
#   'Baskin Robbins',
#   'SUBWAY',
#   'Mobil'],
#  ["Stewart's Shops",
#   "Dunkin' Donuts",
#   'Cumberland Farms',
#   'mcdonalds',
#   'walmart',
#   'Hannaford Supermarkets',
#   'Dollar Tree',
#   'SUBWAY',
#   'Sunoco',
#   'Rite Aid'],
#  ["Dunkin' Donuts",
#   'mcdonalds',
#   'walmart',
#   'Sunoco',
#   'Mobil',
#   'SUBWAY',
#   "Stewart's Shops",
#   'Cumberland Farms',
#   'CVS',
#   'starbucks'],
#  ["Dunkin' Donuts",
#   'CVS',
#   'Costco Wholesale Corp.',
#   'ShopRite',
#   'Stop & Shop',
#   "Dave & Buster's",
#   'mcdonalds',
#   'BP',
#   'Party City',
#   'starbucks'],
#  ["Stewart's Shops",
#   "Dunkin' Donuts",
#   'Sunoco',
#   'Hannaford Supermarkets',
#   'mcdonalds',
#   'walmart',
#   'Price Chopper',
#   'Rite Aid',
#   "Lowe's",
#   'Cumberland Farms'],
#  ["Stewart's Shops",
#   "Dunkin' Donuts",
#   'Cumberland Farms',
#   'walmart',
#   'mcdonalds',
#   'Price Chopper',
#   'Sunoco',
#   'Dollar Tree',
#   'CVS',
#   'Hannaford Supermarkets'],
#  ['mcdonalds',
#   "Dunkin' Donuts",
#   'Sunoco',
#   'walmart',
#   "Stewart's Shops",
#   'SUBWAY',
#   'Mobil',
#   'Burger King US',
#   'Pilot Travel Centers',
#   'Dollar Tree'],
#  ['7-Eleven US',
#   "Dunkin' Donuts",
#   'CVS',
#   'starbucks',
#   'mcdonalds',
#   'Target',
#   'Stop & Shop',
#   'Dollar Tree',
#   'Speedway',
#   'BP'],
#  ['7-Eleven US',
#   "Dunkin' Donuts",
#   'CVS',
#   'mcdonalds',
#   'starbucks',
#   'Speedway',
#   'Stop & Shop',
#   'BP',
#   'Dollar Tree',
#   'Target'],
#  ['7-Eleven US',
#   "Dunkin' Donuts",
#   'CVS',
#   'mcdonalds',
#   'starbucks',
#   'Stop & Shop',
#   'King Kullen Grocery Co.',
#   'Speedway',
#   'Best Market',
#   'The Home Depot'],
#  ["Dunkin' Donuts",
#   'Sunoco',
#   'Wegmans Food Markets',
#   'walmart',
#   'mcdonalds',
#   'Tops Friendly Markets',
#   "Lowe's",
#   'Dollar General',
#   "Applebee's",
#   'Rite Aid'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Family Dollar Stores',
#   "Bojangles'",
#   "Hardee's",
#   "Lowe's",
#   'Food Lion',
#   'Chick-fil-A',
#   'Sheetz'],
#  ['walmart',
#   'mcdonalds',
#   'Chick-fil-A',
#   'QuikTrip',
#   'Shell Oil',
#   'SUBWAY',
#   "Bojangles'",
#   "Wendy's",
#   'Exxon Mobil',
#   'BP'],
#  ['walmart',
#   'Food Lion',
#   '7-Eleven US',
#   'mcdonalds',
#   'Dollar General',
#   'Shell Oil',
#   'Chick-fil-A',
#   "Hardee's",
#   'Speedway',
#   'Exxon Mobil'],
#  ['mcdonalds',
#   'Sheetz',
#   'walmart',
#   'Chick-fil-A',
#   'Food Lion',
#   "Bojangles'",
#   'BP',
#   "Wendy's",
#   'Dollar Tree',
#   'SUBWAY'],
#  ['mcdonalds',
#   'walmart',
#   'Chick-fil-A',
#   "Bojangles'",
#   'Food Lion',
#   'Shell Oil',
#   'Dollar General',
#   'SUBWAY',
#   'Sheetz',
#   "Wendy's"],
#  ['walmart',
#   'Chick-fil-A',
#   'Ingles Markets',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Einstein Brothers',
#   "Bojangles'",
#   'starbucks',
#   'Dollar General',
#   'SUBWAY'],
#  ['walmart',
#   'Shell Oil',
#   'QuikTrip',
#   'mcdonalds',
#   "Bojangles'",
#   'Exxon Mobil',
#   'Chick-fil-A',
#   'Circle K Stores',
#   'Family Dollar Stores',
#   "Wendy's"],
#  ['walmart',
#   'Chick-fil-A',
#   'mcdonalds',
#   'Shell Oil',
#   "Bojangles'",
#   'QuikTrip',
#   'Exxon Mobil',
#   'BP',
#   'Food Lion',
#   'Circle K Stores'],
#  ['walmart',
#   'mcdonalds',
#   'Shell Oil',
#   'QuikTrip',
#   "Bojangles'",
#   'Circle K Stores',
#   'Family Dollar Stores',
#   'Exxon Mobil',
#   'Chick-fil-A',
#   'BP'],
#  ['mcdonalds',
#   'walmart',
#   'Chick-fil-A',
#   'Shell Oil',
#   'BP',
#   'Exxon Mobil',
#   "Bojangles'",
#   'starbucks',
#   "Wendy's",
#   'QuikTrip'],
#  ['walmart',
#   'mcdonalds',
#   'Food Lion',
#   "Lowe's",
#   "Bojangles'",
#   'Speedway',
#   'Exxon Mobil',
#   'BP',
#   'Handy Mart',
#   'Chick-fil-A'],
#  ['walmart',
#   'Chick-fil-A',
#   'mcdonalds',
#   "Bojangles'",
#   'Food Lion',
#   "Lowe's",
#   'Dollar General',
#   "Wendy's",
#   'Exxon Mobil',
#   'Speedway'],
#  ['walmart',
#   'mcdonalds',
#   'Dollar General',
#   "Bojangles'",
#   'Sheetz',
#   'Chick-fil-A',
#   "Lowe's",
#   'CITGO Petroleum',
#   'Food Lion',
#   'BP'],
#  ['Ingles Markets',
#   'walmart',
#   'mcdonalds',
#   'Shell Oil',
#   'Dollar General',
#   'Chick-fil-A',
#   "Lowe's",
#   'Exxon Mobil',
#   "Bojangles'",
#   'SUBWAY'],
#  ['mcdonalds',
#   'walmart',
#   'Dollar General',
#   'Kroger',
#   'Sheetz',
#   'Marathon Petroleum',
#   "Wendy's",
#   'BP',
#   'Burger King US',
#   'Dairy Queen'],
#  ['mcdonalds',
#   'Kroger',
#   "Wendy's",
#   "Frisch's Big Boy",
#   'Speedway',
#   'Skyline Chili',
#   'walmart',
#   'Fred Meyer Jewelers',
#   'starbucks',
#   'Marathon Petroleum'],
#  ['mcdonalds',
#   'walmart',
#   'Speedway',
#   'Kroger',
#   "Wendy's",
#   'BP',
#   'Taco Bell',
#   'Dollar General',
#   'Meijer',
#   'SUBWAY'],
#  ['Giant Eagle',
#   'mcdonalds',
#   'Family Dollar Stores',
#   'walmart',
#   'Speedway',
#   'SUBWAY',
#   'BP',
#   'Burger King US',
#   "Wendy's",
#   'Target'],
#  ['mcdonalds',
#   'Family Dollar Stores',
#   'Sunoco',
#   'Dollar General',
#   'Save-A-Lot (Onex)',
#   'walmart',
#   'Speedway',
#   "Wendy's",
#   'Marathon Petroleum',
#   'Burger King US'],
#  ['mcdonalds',
#   'Giant Eagle',
#   "Wendy's",
#   'BP',
#   'walmart',
#   'Speedway',
#   'SUBWAY',
#   'Family Dollar Stores',
#   'Sunoco',
#   'CVS'],
#  ['Kroger',
#   "Wendy's",
#   'mcdonalds',
#   'starbucks',
#   'Speedway',
#   'Tim Hortons',
#   'SUBWAY',
#   'BP',
#   'Giant Eagle',
#   'Target'],
#  ['mcdonalds',
#   'Kroger',
#   'Speedway',
#   'walmart',
#   "Wendy's",
#   'SUBWAY',
#   'Taco Bell',
#   'starbucks',
#   'Meijer',
#   'Marathon Petroleum'],
#  ['Giant Eagle',
#   'mcdonalds',
#   'Speedway',
#   'walmart',
#   "Wendy's",
#   'Shell Oil',
#   'BP',
#   'Target',
#   'CVS',
#   'Chipotle Mexican Grill'],
#  ['Speedway',
#   'mcdonalds',
#   'Kroger',
#   'walmart',
#   "Wendy's",
#   'Taco Bell',
#   'SUBWAY',
#   'Meijer',
#   'Burger King US',
#   'Marathon Petroleum'],
#  ['mcdonalds',
#   'walmart',
#   'Giant Eagle',
#   'Sheetz',
#   'Speedway',
#   'Dollar General',
#   'Circle K Stores',
#   'BP',
#   "Wendy's",
#   'Marathon Petroleum'],
#  ['Giant Eagle',
#   'walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Sheetz',
#   "Dunkin' Donuts",
#   "Wendy's",
#   'Residence Inn by Marriott',
#   'BP',
#   'Burger King US'],
#  ['walmart',
#   'Sonic',
#   'Phillips 66',
#   'mcdonalds',
#   "Braum's Ice Cream and Dairy Stores",
#   'Dollar General',
#   'OnCue',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Walgreens'],
#  ['walmart',
#   'mcdonalds',
#   'QuikTrip',
#   'Sonic',
#   'Phillips 66',
#   'SUBWAY',
#   'Dollar General',
#   "Braum's Ice Cream and Dairy Stores",
#   "Love's Travel Stops and Country Stores",
#   "Arby's"],
#  ['walmart',
#   'mcdonalds',
#   'QuikTrip',
#   'SUBWAY',
#   'Sonic',
#   'Phillips 66',
#   'Kum & Go',
#   'Dollar General',
#   'Pilot Travel Centers',
#   "Love's Travel Stops and Country Stores"],
#  ['QuikTrip',
#   'walmart',
#   'mcdonalds',
#   'Dollar General',
#   'Sonic',
#   'Kum & Go',
#   'Family Dollar Stores',
#   'Walgreens',
#   "Braum's Ice Cream and Dairy Stores",
#   'SUBWAY'],
#  ['walmart',
#   'Chevron',
#   'Taco Bell',
#   'Dutch Bros Coffee',
#   'Goodwill Industries',
#   'mcdonalds',
#   'Shell Oil',
#   'Safeway',
#   'SUBWAY',
#   'starbucks'],
#  ['starbucks',
#   'Fred Meyer Jewelers',
#   'Costco Wholesale Corp.',
#   'Safeway',
#   'Albertsons Market',
#   'Fred Meyer',
#   'mcdonalds',
#   'Taco Bell',
#   'walmart',
#   "Carl's Jr."],
#  ['starbucks',
#   'Fred Meyer',
#   'Safeway',
#   'Fred Meyer Jewelers',
#   '7-Eleven US',
#   'mcdonalds',
#   'Taco Bell',
#   'Goodwill Industries',
#   'WinCo Foods',
#   'Chevron'],
#  ['starbucks',
#   'WinCo Foods',
#   'Dutch Bros Coffee',
#   'mcdonalds',
#   'Fred Meyer',
#   'Dollar Tree',
#   'Fred Meyer Jewelers',
#   'Safeway',
#   'walmart',
#   'Shell Oil'],
#  ['Giant Eagle',
#   'Sheetz',
#   'mcdonalds',
#   'walmart',
#   'starbucks',
#   "Wendy's",
#   'Target',
#   "Dunkin' Donuts",
#   'Sunoco',
#   "Eat'n Park"],
#  ['Giant Eagle',
#   'mcdonalds',
#   'Sheetz',
#   'walmart',
#   "Wendy's",
#   'Dollar General',
#   'Dollar Tree',
#   'SHOP ‚Äôn SAVE Supermarkets',
#   'Sunoco',
#   'Rite Aid'],
#  ['Sheetz',
#   'Giant Eagle',
#   'walmart',
#   'Dollar General',
#   'Dollar Tree',
#   'mcdonalds',
#   'Burger King US',
#   "Wendy's",
#   "Eat'n Park",
#   'BP'],
#  ['Wawa',
#   'Pet Valu',
#   'walmart',
#   "Dunkin' Donuts",
#   'Dollar Tree',
#   'CVS',
#   'mcdonalds',
#   'Giant Food Stores',
#   'GameStop',
#   'Chick-fil-A'],
#  ['Wawa',
#   "Dunkin' Donuts",
#   'mcdonalds',
#   'CVS',
#   'Sunoco',
#   'walmart',
#   '7-Eleven US',
#   'ShopRite',
#   'starbucks',
#   'Dollar Tree'],
#  ['Sheetz',
#   'mcdonalds',
#   'Giant Food Stores',
#   'walmart',
#   'Weis Markets',
#   'Pet Valu',
#   'Sunoco',
#   'starbucks',
#   'Pennsylvania Real Estate and Investment Trust (PREIT)',
#   'Rite Aid'],
#  ['Wawa',
#   "Dunkin' Donuts",
#   'CVS',
#   'Sunoco',
#   'mcdonalds',
#   'Giant Food Stores',
#   'Family Dollar Stores',
#   'Rite Aid',
#   'Dollar Tree',
#   'Acme Markets'],
#  ['Sheetz',
#   'walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Giant Eagle',
#   'Sunoco',
#   'SUBWAY',
#   'United States Postal Service (USPS)',
#   "Eat'n Park",
#   'Napa Auto Parts'],
#  ["Dunkin' Donuts",
#   'Quick Lane',
#   'walmart',
#   'mcdonalds',
#   'Wawa',
#   'Sunoco',
#   'Exxon Mobil',
#   'Dollar Tree',
#   'ShopRite',
#   "Wendy's"],
#  ['Wawa',
#   "Dunkin' Donuts",
#   'Sunoco',
#   'Rite Aid',
#   'Dollar Tree',
#   'mcdonalds',
#   'CVS',
#   '7-Eleven US',
#   'Target',
#   'ShopRite'],
#  ["Dunkin' Donuts",
#   'Sunoco',
#   'mcdonalds',
#   'walmart',
#   'The Home Depot',
#   'CVS',
#   "Wendy's",
#   'T.J. Maxx',
#   'Dollar Tree',
#   'Burger King US'],
#  ['Sunoco',
#   "Dunkin' Donuts",
#   'Weis Markets',
#   'mcdonalds',
#   'CVS',
#   'Turkey Hill',
#   'Dollar General',
#   'The Home Depot',
#   'Pennsylvania Real Estate and Investment Trust (PREIT)',
#   'GameStop'],
#  ['mcdonalds',
#   'Sheetz',
#   'walmart',
#   "Rutter's Farm Stores",
#   'SUBWAY',
#   'Sunoco',
#   "Dunkin' Donuts",
#   'Giant Food Stores',
#   'Burger King US',
#   "Wendy's"],
#  ['Sheetz',
#   'walmart',
#   'mcdonalds',
#   "Rutter's Farm Stores",
#   'SUBWAY',
#   'Royal Farms',
#   'Dollar General',
#   'Giant Food Stores',
#   'Burger King US',
#   'Chick-fil-A'],
#  ['walmart',
#   'Chick-fil-A',
#   'mcdonalds',
#   'Circle K Stores',
#   'BP',
#   'Shell Oil',
#   'Sunoco',
#   'SUBWAY',
#   "Wendy's",
#   'Exxon Mobil'],
#  ['walmart',
#   'Chick-fil-A',
#   'mcdonalds',
#   'Shell Oil',
#   'BP',
#   'Circle K Stores',
#   'CVS',
#   'Sunoco',
#   "Lowe's",
#   'Publix Super Markets'],
#  ['walmart',
#   'BP',
#   'mcdonalds',
#   'Shell Oil',
#   'Circle K Stores',
#   'SUBWAY',
#   'Dollar General',
#   'Chick-fil-A',
#   'BI-LO',
#   "Wendy's"],
#  ['Chick-fil-A',
#   'mcdonalds',
#   'Shell Oil',
#   'Circle K Stores',
#   'walmart',
#   'BP',
#   'starbucks',
#   'Publix Super Markets',
#   "Bojangles'",
#   'SUBWAY'],
#  ['walmart',
#   'mcdonalds',
#   'Chick-fil-A',
#   'Shell Oil',
#   'BP',
#   'Circle K Stores',
#   'Dollar General',
#   'Exxon Mobil',
#   'Food Lion',
#   "Bojangles'"],
#  ['walmart',
#   'ConocoPhillips',
#   'Sinclair Oil',
#   "Menard's",
#   'mcdonalds',
#   'Do It Best',
#   'Dairy Queen',
#   'Holiday Station',
#   'SUBWAY',
#   "Taco John's"],
#  ['walmart',
#   'mcdonalds',
#   'Einstein Brothers',
#   'Safeway',
#   "Taco John's",
#   'Qdoba Mexican Grill',
#   'ConocoPhillips',
#   'Perkins Restaurant & Bakery',
#   'Sinclair Oil',
#   'Phillips 66'],
#  ['walmart',
#   'mcdonalds',
#   'Food City',
#   'Dollar General',
#   'Chick-fil-A',
#   'Kroger',
#   'Walgreens',
#   'Sonic',
#   'Taco Bell',
#   'Shell Oil'],
#  ['walmart',
#   'mcdonalds',
#   'Shell Oil',
#   'Kroger',
#   'Dollar General',
#   'Sonic',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Walgreens',
#   "Wendy's"],
#  ['Kroger',
#   'Shell Oil',
#   'mcdonalds',
#   'walmart',
#   'Walgreens',
#   'Dollar General',
#   'Sonic',
#   'Exxon Mobil',
#   'SUBWAY',
#   'starbucks'],
#  ['walmart',
#   'Sonic',
#   'mcdonalds',
#   'Dollar General',
#   'Shell Oil',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Marathon Petroleum',
#   'Exxon Mobil',
#   'Murphy USA'],
#  ['walmart',
#   'mcdonalds',
#   'BP',
#   'Dollar General',
#   'Chick-fil-A',
#   'SUBWAY',
#   'Sonic',
#   'Taco Bell',
#   'Food City',
#   "Wendy's"],
#  ['walmart',
#   'mcdonalds',
#   'BP',
#   'Chick-fil-A',
#   'Dollar General',
#   'SUBWAY',
#   'Taco Bell',
#   "Wendy's",
#   'Sonic',
#   'Food City'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'BP',
#   'Sonic',
#   'SUBWAY',
#   "Hardee's",
#   'Shell Oil',
#   'Taco Bell',
#   'Cracker Barrel'],
#  ['Kroger',
#   'Chick-fil-A',
#   'Walgreens',
#   'mcdonalds',
#   'starbucks',
#   'walmart',
#   'Exxon Mobil',
#   'Sonic',
#   'Shell Oil',
#   'Target'],
#  ['H-E-B',
#   'walmart',
#   'Bill Miller Bar-B-Q',
#   'mcdonalds',
#   'Circle K Stores',
#   'Valero Energy',
#   'Whataburger',
#   'Shell Oil',
#   'Family Dollar Stores',
#   'Exxon Mobil'],
#  ['walmart',
#   'mcdonalds',
#   'Sonic',
#   'Shell Oil',
#   'Exxon Mobil',
#   'SUBWAY',
#   'Dollar General',
#   'E-Z Mart',
#   'Whataburger',
#   'Pilot Travel Centers'],
#  ['starbucks',
#   'walmart',
#   '7-Eleven US',
#   'Exxon Mobil',
#   'Whataburger',
#   'mcdonalds',
#   'Chick-fil-A',
#   'Shell Oil',
#   'QuikTrip',
#   'CVS'],
#  ['walmart',
#   'starbucks',
#   'mcdonalds',
#   'QuikTrip',
#   'Chick-fil-A',
#   '7-Eleven US',
#   'Exxon Mobil',
#   'Whataburger',
#   'Shell Oil',
#   'Sonic'],
#  ['walmart',
#   'starbucks',
#   '7-Eleven US',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Chick-fil-A',
#   'QuikTrip',
#   'Whataburger',
#   'CVS',
#   'SUBWAY'],
#  ['walmart',
#   'Whataburger',
#   'mcdonalds',
#   'QuikTrip',
#   'starbucks',
#   'Chick-fil-A',
#   'Sonic',
#   'Exxon Mobil',
#   'Shell Oil',
#   '7-Eleven US'],
#  ['walmart',
#   'Exxon Mobil',
#   'Whataburger',
#   'QuikTrip',
#   'mcdonalds',
#   '7-Eleven US',
#   'Sonic',
#   'Jack in the Box',
#   'Shell Oil',
#   'Chick-fil-A'],
#  ['walmart',
#   'QuikTrip',
#   'mcdonalds',
#   'Family Dollar Stores',
#   'Whataburger',
#   'RaceTrac',
#   '7-Eleven US',
#   'Shell Oil',
#   'Jack in the Box',
#   'Exxon Mobil'],
#  ['walmart',
#   'starbucks',
#   'Whataburger',
#   'mcdonalds',
#   'Chick-fil-A',
#   'QuikTrip',
#   'Sonic',
#   'Exxon Mobil',
#   '7-Eleven US',
#   'RaceTrac'],
#  ['walmart',
#   'Chick-fil-A',
#   'Whataburger',
#   'starbucks',
#   'Sonic',
#   'mcdonalds',
#   'QuikTrip',
#   'SUBWAY',
#   'Exxon Mobil',
#   '7-Eleven US'],
#  ['Stripes Convenience Stores',
#   'walmart',
#   'H-E-B',
#   'Dollar General',
#   'Alon USA',
#   'Sonic',
#   'Whataburger',
#   'mcdonalds',
#   'Dairy Queen',
#   'Texaco'],
#  ['walmart',
#   'Family Dollar Stores',
#   'Alon USA',
#   'Circle K Stores',
#   'Dollar Tree',
#   'Whataburger',
#   'mcdonalds',
#   'Valero Energy',
#   'Peter Piper Pizza',
#   'Walgreens'],
#  ['walmart',
#   'Whataburger',
#   'H-E-B',
#   'Shell Oil',
#   'Exxon Mobil',
#   'Sonic',
#   'Valero Energy',
#   'mcdonalds',
#   "Buc-ee's",
#   'SUBWAY'],
#  ['walmart',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Whataburger',
#   'H-E-B',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Kroger',
#   'Walgreens',
#   'Chevron'],
#  ['H-E-B',
#   'walmart',
#   'Whataburger',
#   'Shell Oil',
#   'Exxon Mobil',
#   'Valero Energy',
#   'Sonic',
#   'mcdonalds',
#   'Chick-fil-A',
#   'SUBWAY'],
#  ['walmart',
#   'Whataburger',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   'mcdonalds',
#   'Chevron',
#   'starbucks',
#   'Sonic',
#   'Valero Energy'],
#  ['walmart',
#   'Shell Oil',
#   'Whataburger',
#   'mcdonalds',
#   'Exxon Mobil',
#   'Chevron',
#   'Jack in the Box',
#   'Chick-fil-A',
#   'Valero Energy',
#   'Family Dollar Stores'],
#  ['walmart',
#   'Stripes Convenience Stores',
#   'H-E-B',
#   'Sonic',
# ...
#   'CVS',
#   'Cumberland Farms',
#   'Anytime Fitness',
#   'Shell Oil',
#   'The Home Depot',
#   'Rite Aid',
#   'starbucks',
#   'Pet Valu'],
#  ['QuikTrip',
#   'Chick-fil-A',
#   'walmart',
#   'Spinx',
#   'mcdonalds',
#   'CVS',
#   'Dollar General',
#   "Bojangles'",
#   'starbucks',
#   "Zaxby's"],
#  ['walmart',
#   'mcdonalds',
#   'Circle K Stores',
#   'BP',
#   'Chick-fil-A',
#   'Dollar General',
#   "Bojangles'",
#   "Lowe's",
#   'Shell Oil',
#   'CVS'],
#  ['walmart',
#   'mcdonalds',
#   'BP',
#   'Circle K Stores',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Food Lion',
#   'Exxon Mobil',
#   'Dollar General',
#   "Bojangles'"],
#  ['walmart',
#   'Chick-fil-A',
#   'Ingles Markets',
#   'mcdonalds',
#   'Dollar General',
#   'QuikTrip',
#   'SUBWAY',
#   'Exxon Mobil',
#   "Bojangles'",
#   'starbucks'],
#  ['Shell Oil',
#   'walmart',
#   'Dollar General',
#   'Circle K Stores',
#   'mcdonalds',
#   'BP',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   "Bojangles'",
#   "Lowe's"],
#  ['QuikTrip',
#   'walmart',
#   'Chick-fil-A',
#   'Dollar General',
#   'mcdonalds',
#   'Ingles Markets',
#   'SUBWAY',
#   "Bojangles'",
#   'Spinx',
#   "Zaxby's"],
#  ['Hy-Vee',
#   'walmart',
#   'BP',
#   'Lewis Drug',
#   'mcdonalds',
#   'Holiday Station',
#   'Burger King US',
#   "Casey's General Stores",
#   'Target',
#   "Culver's"],
#  ['walmart',
#   'mcdonalds',
#   'Shell Oil',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Dollar General',
#   'Pilot Travel Centers',
#   'BP',
#   "Wendy's",
#   'Cracker Barrel'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Exxon Mobil',
#   'Shell Oil',
#   'SUBWAY',
#   'Taco Bell',
#   'Cracker Barrel',
#   'Sonic',
#   "Hardee's"],
#  ['Dollar General'],
#  ['Kroger',
#   'Food City',
#   'Dollar General',
#   'Sonic',
#   "Bojangles'",
#   'Cracker Barrel',
#   "Zaxby's"],
#  ['walmart',
#   'Kroger',
#   'mcdonalds',
#   'Walgreens',
#   'Exxon Mobil',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Sonic',
#   'Family Dollar Stores',
#   "Wendy's"],
#  ['mcdonalds',
#   'walmart',
#   'Exxon Mobil',
#   'Family Dollar Stores',
#   'Walgreens',
#   'Kroger',
#   'Shell Oil',
#   'Dollar General',
#   'Marathon Petroleum',
#   'SUBWAY'],
#  ['H-E-B',
#   'walmart',
#   'Circle K Stores',
#   'Whataburger',
#   'Valero Energy',
#   'mcdonalds',
#   'Bill Miller Bar-B-Q',
#   'Shell Oil',
#   'Exxon Mobil',
#   'Taco Cabana'],
#  ['H-E-B',
#   'walmart',
#   'Whataburger',
#   'Exxon Mobil',
#   'Shell Oil',
#   'Valero Energy',
#   'Sonic',
#   'mcdonalds',
#   'Chick-fil-A',
#   'SUBWAY'],
#  ['walmart',
#   'starbucks',
#   'Chick-fil-A',
#   'Whataburger',
#   'Sonic',
#   'RaceTrac',
#   'mcdonalds',
#   'Target',
#   'QuikTrip',
#   'Kroger'],
#  ['walmart',
#   'starbucks',
#   'Chick-fil-A',
#   'Whataburger',
#   'RaceTrac',
#   'mcdonalds',
#   'Sonic',
#   'QuikTrip',
#   'Kroger',
#   'Target'],
#  ['walmart',
#   'mcdonalds',
#   'Exxon Mobil',
#   '7-Eleven US',
#   'QuikTrip',
#   'Shell Oil',
#   'Family Dollar Stores',
#   'Jack in the Box',
#   'Whataburger',
#   'SUBWAY'],
#  ['walmart',
#   'QuikTrip',
#   'mcdonalds',
#   'Whataburger',
#   'starbucks',
#   'Shell Oil',
#   '7-Eleven US',
#   'Exxon Mobil',
#   'Chick-fil-A',
#   'Sonic'],
#  ['walmart',
#   'Whataburger',
#   'starbucks',
#   '7-Eleven US',
#   'RaceTrac',
#   'QuikTrip',
#   'mcdonalds',
#   'Chick-fil-A',
#   'Kroger',
#   'Sonic'],
#  ['walmart',
#   'H-E-B',
#   'Sonic',
#   'Whataburger',
#   "Buc-ee's",
#   'Exxon Mobil',
#   'mcdonalds',
#   'Dollar General',
#   'Shell Oil',
#   'Jack in the Box'],
#  ['starbucks',
#   'Whataburger',
#   'Chick-fil-A',
#   'walmart',
#   'Kroger',
#   'H-E-B',
#   'mcdonalds',
#   'Walgreens',
#   'Sonic',
#   'Shell Oil'],
#  ['walmart',
#   'Shell Oil',
#   'H-E-B',
#   'starbucks',
#   'Whataburger',
#   'mcdonalds',
#   'Walgreens',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   'Chevron'],
#  ['walmart',
#   'Shell Oil',
#   'Whataburger',
#   'mcdonalds',
#   'Chick-fil-A',
#   'starbucks',
#   'Exxon Mobil',
#   'H-E-B',
#   'Chevron',
#   'Walgreens'],
#  ['walmart',
#   'Shell Oil',
#   'mcdonalds',
#   'Whataburger',
#   'Exxon Mobil',
#   'Chevron',
#   'Chick-fil-A',
#   'Valero Energy',
#   'Family Dollar Stores',
#   'Jack in the Box'],
#  ['walmart',
#   'Whataburger',
#   'mcdonalds',
#   'Shell Oil',
#   'Chick-fil-A',
#   'starbucks',
#   'Walgreens',
#   'Exxon Mobil',
#   'Chevron',
#   'Kroger'],
#  ['walmart',
#   'Stripes Convenience Stores',
#   'Whataburger',
#   'H-E-B',
#   'Valero Energy',
#   'mcdonalds',
#   "Buddy's",
#   'Sunoco',
#   'Chick-fil-A',
#   'SUBWAY'],
#  ['walmart',
#   'mcdonalds',
#   'SUBWAY',
#   'Exxon Mobil',
#   'Shell Oil',
#   'Sonic',
#   'Pilot Travel Centers',
#   'Whataburger',
#   "Love's Travel Stops and Country Stores",
#   'Valero Energy'],
#  ['Sonic',
#   'walmart',
#   'Exxon Mobil',
#   'Time Warner Cable',
#   'Market Basket Foods',
#   'mcdonalds',
#   'Shell Oil',
#   'Dairy Queen',
#   'Walgreens',
#   'Whataburger'],
#  ['walmart',
#   'Sonic',
#   'Exxon Mobil',
#   'Whataburger',
#   'Shell Oil',
#   'mcdonalds',
#   'Dollar General',
#   'QuikTrip',
#   'Chicken Express',
#   'Valero Energy'],
#  ['walmart',
#   'Shell Oil',
#   'Whataburger',
#   'mcdonalds',
#   'Exxon Mobil',
#   'Sonic',
#   'SUBWAY',
#   'Chick-fil-A',
#   'starbucks',
#   "Buc-ee's"],
#  ['walmart',
#   'Chick-fil-A',
#   'Sonic',
#   'Whataburger',
#   'starbucks',
#   'mcdonalds',
#   'Phillips 66',
#   'United Supermarkets',
#   'Stripes Convenience Stores',
#   'Target'],
#  ['walmart',
#   'United Supermarkets',
#   'Sonic',
#   'Phillips 66',
#   'Valero Energy',
#   'mcdonalds',
#   'Dollar General',
#   'Walgreens',
#   'Chick-fil-A',
#   'Whataburger'],
#  ['walmart',
#   'Whataburger',
#   'Exxon Mobil',
#   'Sonic',
#   'Valero Energy',
#   "Brookshire's Grocery Company",
#   'Dairy Queen',
#   'mcdonalds',
#   'Chick-fil-A',
#   'Dollar General'],
#  ['Exxon Mobil', 'Sonic', 'Whataburger'],
#  ["Smith's Food & Drug Stores",
#   'Costco Wholesale Corp.',
#   'Associated Food Stores',
#   'walmart',
#   'mcdonalds',
#   'Chevron',
#   'Maverik',
#   'Fred Meyer Jewelers',
#   "Wendy's",
#   'Sinclair Oil'],
#  ["Smith's Food & Drug Stores",
#   'mcdonalds',
#   'Chevron',
#   'walmart',
#   'Sinclair Oil',
#   '7-Eleven US',
#   'Associated Food Stores',
#   'Costco Wholesale Corp.',
#   'Corner Bakery Cafe',
#   'starbucks'],
#  ['walmart',
#   'Associated Food Stores',
#   "Smith's Food & Drug Stores",
#   'Chevron',
#   'mcdonalds',
#   'Costco Wholesale Corp.',
#   'Maverik',
#   'Target',
#   'Chick-fil-A',
#   'Taco Bell'],
#  ['walmart',
#   'Associated Food Stores',
#   "Smith's Food & Drug Stores",
#   'mcdonalds',
#   'Chevron',
#   'Costco Wholesale Corp.',
#   'Maverik',
#   "Wendy's",
#   'Taco Bell',
#   'Chick-fil-A'],
#  ['walmart',
#   'mcdonalds',
#   'Chevron',
#   'Costco Wholesale Corp.',
#   'Maverik',
#   "Wendy's",
#   'Associated Food Stores',
#   'SUBWAY',
#   "Smith's Food & Drug Stores",
#   "Arby's"],
#  ['walmart',
#   'Costco Wholesale Corp.',
#   "Smith's Food & Drug Stores",
#   'mcdonalds',
#   'Chevron',
#   'Chick-fil-A',
#   'Costa Vida',
#   'Maverik',
#   'Associated Food Stores',
#   "Wendy's"],
#  ['Mobil',
#   'Hannaford Supermarkets',
#   'Dollar General',
#   'Cumberland Farms',
#   'Irving Oil',
#   "Dunkin' Donuts",
#   'Rite Aid',
#   'walmart',
#   'mcdonalds',
#   'Sunoco'],
#  ['mcdonalds',
#   '7-Eleven US',
#   'starbucks',
#   'walmart',
#   'Sheetz',
#   'Chick-fil-A',
#   'SUBWAY',
#   'Exxon Mobil',
#   'Shell Oil',
#   'Target'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Marathon Petroleum',
#   "Hardee's",
#   'Food City',
#   'Family Dollar Stores',
#   'SUBWAY',
#   'BP',
#   'Cracker Barrel'],
#  ['walmart',
#   'mcdonalds',
#   'Sheetz',
#   "Wendy's",
#   'Dollar General',
#   'Exxon Mobil',
#   "Lowe's",
#   "Hardee's",
#   'SUBWAY',
#   'Cracker Barrel'],
#  ['7-Eleven US',
#   'mcdonalds',
#   'SUBWAY',
#   'Chick-fil-A',
#   'walmart',
#   'starbucks',
#   'Sheetz',
#   'Exxon Mobil',
#   'Costco Wholesale Corp.',
#   'Target'],
#  ['7-Eleven US',
#   'mcdonalds',
#   'walmart',
#   'Chick-fil-A',
#   'SUBWAY',
#   'Exxon Mobil',
#   'starbucks',
#   'Sheetz',
#   'Wawa',
#   'Target'],
#  ['7-Eleven US',
#   'walmart',
#   'Wawa',
#   'Food Lion',
#   'Chick-fil-A',
#   'mcdonalds',
#   'Pennsylvania Real Estate and Investment Trust (PREIT)',
#   "Wendy's",
#   'Dollar Tree',
#   'SUBWAY'],
#  ['Sheetz',
#   '7-Eleven US',
#   "MARTIN'S Food Markets",
#   'Exxon Mobil',
#   'mcdonalds',
#   'Chick-fil-A',
#   'walmart'],
#  ['starbucks',
#   'Fred Meyer',
#   'walmart',
#   'Fred Meyer Jewelers',
#   'Costco Wholesale Corp.',
#   'WinCo Foods',
#   'Burgerville',
#   'Chevron',
#   'Dollar Tree',
#   'Safeway'],
#  ['starbucks',
#   'mcdonalds',
#   'Safeway',
#   'walmart',
#   'Fred Meyer',
#   'Chevron',
#   'Fred Meyer Jewelers',
#   'WinCo Foods',
#   'Costco Wholesale Corp.',
#   'Taco Bell'],
#  ['starbucks',
#   'Safeway',
#   'Costco Wholesale Corp.',
#   '76',
#   'Bartell Drugs',
#   'Shell Oil',
#   'Chevron',
#   'SUBWAY',
#   'mcdonalds',
#   '7-Eleven US'],
#  ['starbucks',
#   'Safeway',
#   'Costco Wholesale Corp.',
#   'Fred Meyer Jewelers',
#   'mcdonalds',
#   'Chevron',
#   '76',
#   'Shell Oil',
#   'ARCO',
#   'Jack in the Box'],
#  ['mcdonalds',
#   'starbucks',
#   'walmart',
#   'Costco Wholesale Corp.',
#   'Safeway',
#   'SUBWAY',
#   'ConocoPhillips',
#   'WinCo Foods',
#   'Dutch Bros Coffee',
#   'Albertsons Market'],
#  ['mcdonalds',
#   'walmart',
#   'Sheetz',
#   "Wendy's",
#   'Dollar General',
#   'Taco Bell',
#   'Kroger',
#   'Exxon Mobil',
#   'Speedway',
#   'SUBWAY'],
#  ['Sheetz',
#   'mcdonalds',
#   'walmart',
#   'SUBWAY',
#   'Dollar General',
#   'Exxon Mobil',
#   '7-Eleven US',
#   'BP',
#   'Pilot Travel Centers',
#   'Chick-fil-A'],
#  ['mcdonalds',
#   'walmart',
#   "Wendy's",
#   'Sheetz',
#   'SUBWAY',
#   'Exxon Mobil',
#   'Speedway',
#   'Dollar General',
#   'Taco Bell',
#   'Kroger'],
#  ['SmartStyle Family Hair Salons'],
#  ['SmartStyle Family Hair Salons'],
#  ['Fresenius Medical Care North America'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   "Jack's Family Restaurants",
#   'Chevron',
#   'Piggly Wiggly',
#   'Burger King US',
#   'Marathon Petroleum',
#   "Zaxby's",
#   'Chick-fil-A'],
#  ['walmart',
#   'Dollar General',
#   "Jack's Family Restaurants",
#   'mcdonalds',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Chevron',
#   'Burger King US',
#   'SUBWAY',
#   'Taco Bell'],
#  ['walmart',
#   'Shell Oil',
#   'Chevron',
#   'mcdonalds',
#   'Chick-fil-A',
#   'Dollar General',
#   "Jack's Family Restaurants",
#   'SUBWAY',
#   "America's Thrift Store",
#   'Dollar Tree'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   "America's Thrift Store",
#   'Chick-fil-A',
#   'Burger King US',
#   'SUBWAY',
#   'Circle K Stores',
#   'Dollar Tree',
#   'Waffle House'],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Chick-fil-A',
#   "Jack's Family Restaurants",
#   'Shell Oil',
#   'Burger King US',
#   'Chevron',
#   'SUBWAY',
#   "Arby's"],
#  ['walmart',
#   'Dollar General',
#   'mcdonalds',
#   'Chick-fil-A',
#   'Chevron',
#   'Shell Oil',
#   'Winn Dixie',
#   'CVS',
#   "America's Thrift Store",
#   'Circle K Stores'],
#  ['starbucks',
#   'walmart',
#   'mcdonalds',
#   'Holiday Station',
#   'Target',
#   'SUBWAY',
#   'Taco Bell',
#   'Costco Wholesale Corp.',
#   'Chevron',
#   'Fred Meyer Jewelers'],
#  ['walmart',
#   'starbucks',
#   'Circle K Stores',
#   'mcdonalds',
#   'Shell Oil',
#   'SUBWAY',
#   'Chevron',
#   "Fry's Food & Drug Stores",
#   'Target',
#   "Denny's"],
#  ['walmart',
#   'starbucks',
#   'Circle K Stores',
#   "Fry's Food & Drug Stores",
#   'mcdonalds',
#   'QuikTrip',
#   'Walgreens',
#   'Chevron',
#   'The Home Depot',
#   'Jack in the Box'],
#  ['walmart',
#   'Circle K Stores',
#   'QuikTrip',
#   'starbucks',
#   'mcdonalds',
#   "Fry's Food & Drug Stores",
#   'Walgreens',
#   'Jack in the Box',
#   'Chevron',
#   'SUBWAY'],
#  ['Circle K Stores',
#   'starbucks',
#   "Fry's Food & Drug Stores",
#   'mcdonalds',
#   'QuikTrip',
#   'walmart',
#   'Shell Oil',
#   'Walgreens',
#   'Costco Wholesale Corp.',
#   'Chevron'],
#  ['Circle K Stores',
#   'QuikTrip',
#   "Fry's Food & Drug Stores",
#   'walmart',
#   'mcdonalds',
#   'Jack in the Box',
#   'starbucks',
#   'Walgreens',
#   'Chevron',
#   'Burger King US'],
#  ['Circle K Stores',
#   'walmart',
#   'QuikTrip',
#   'mcdonalds',
#   "Fry's Food & Drug Stores",
#   'starbucks',
#   'Walgreens',
#   'Jack in the Box',
#   'Shell Oil',
#   'Chevron'],
#  ['Circle K Stores',
#   "Fry's Food & Drug Stores",
#   'QuikTrip',
#   'walmart',
#   'mcdonalds',
#   'starbucks',
#   'Walgreens',
#   'Jack in the Box',
#   'SUBWAY',
#   'Chevron'],
#  ['Circle K Stores',
#   'walmart',
#   "Fry's Food & Drug Stores",
#   'QuikTrip',
#   'mcdonalds',
#   'starbucks',
#   'Walgreens',
#   'Chevron',
#   'Taco Bell',
#   'Shell Oil'],
#  ['Circle K Stores',
#   'walmart',
#   'QuikTrip',
#   "Fry's Food & Drug Stores",
#   'mcdonalds',
#   'starbucks',
#   'Taco Bell',
#   'Walgreens',
#   'Shell Oil',
#   'Chevron'],
#  ['Circle K Stores',
#   'walmart',
#   'mcdonalds',
#   'QuikTrip',
#   'Dollar Tree',
#   "Fry's Food & Drug Stores",
#   'Walgreens',
#   'Costco Wholesale Corp.',
#   'starbucks',
#   'Family Dollar Stores'],
#  ['Circle K Stores',
#   'walmart',
#   'Dollar Tree',
#   'QuikTrip',
#   'mcdonalds',
#   'Burger King US',
#   'starbucks',
#   'Jack in the Box',
#   "Fry's Food & Drug Stores",
#   'Ross Stores'],
#  ['walmart',
#   'mcdonalds',
#   'Sonic',
#   'Dollar General',
#   'SUBWAY',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Valero Energy',
#   'Kroger',
#   'Exxon Mobil'],
#  ['walmart',
#   'Sonic',
#   'mcdonalds',
#   'Valero Energy',
#   'Dollar General',
#   'Shell Oil',
#   'SUBWAY',
#   'Chick-fil-A',
#   'Walgreens',
#   'Taco Bell'],
#  ['walmart',
#   'Sonic',
#   'Dollar General',
#   'mcdonalds',
#   'Exxon Mobil',
#   'Valero Energy',
#   'Baptist Health',
#   'Shell Oil',
#   'Family Dollar Stores',
#   'SUBWAY'],
#  ['walmart',
#   'Sonic',
#   'mcdonalds',
#   'Dollar General',
#   'SUBWAY',
#   'Phillips 66',
#   'Shell Oil',
#   'Chick-fil-A',
#   'Exxon Mobil',
#   "Casey's General Stores"],
#  ['starbucks',
#   'Chevron',
#   'Safeway',
#   'Costco Wholesale Corp.',
#   'mcdonalds',
#   'Target',
#   'Shell Oil',
#   'ARCO',
#   '7-Eleven US',
#   'SUBWAY'],
#  ['Costco Wholesale Corp.',
#   'Chevron',
#   'mcdonalds',
#   'starbucks',
#   'Target',
#   'Jack in the Box',
#   '76',
#   'walmart',
#   '7-Eleven US',
#   'Safeway'],
#  ['Costco Wholesale Corp.',
#   'starbucks',
#   'Chevron',
#   'Target',
#   'mcdonalds',
#   'Safeway',
#   '7-Eleven US',
#   'In-N-Out Burger',
#   'SUBWAY',
#   'walmart'],
#  ['Costco Wholesale Corp.',
#   'Taco Bell',
#   'ARCO',
#   'Dutch Bros Coffee',
#   'Chevron',
#   'Safeway',
#   'mcdonalds',
#   'WinCo Foods',
#   'starbucks',
#   'walmart'],
#  ['starbucks',
#   'Ralphs',
#   'mcdonalds',
#   'Chevron',
#   'Target',
#   'In-N-Out Burger',
#   'Costco Wholesale Corp.',
#   'Shell Oil',
#   'ARCO',
#   'SUBWAY'],
#  ['mcdonalds',
#   'starbucks',
#   '7-Eleven US',
#   'Jack in the Box',
#   'ARCO',
#   '99 Cents Only Stores',
#   'Target',
#   'Chevron',
#   'Costco Wholesale Corp.',
#   '76'],
#  ['starbucks',
#   'mcdonalds',
#   'ARCO',
#   'Chevron',
#   'Target',
#   'In-N-Out Burger',
#   'Jack in the Box',
#   'SUBWAY',
#   '7-Eleven US',
#   'Costco Wholesale Corp.'],
#  ['mcdonalds',
#   '7-Eleven US',
#   'ARCO',
#   'Jack in the Box',
#   'starbucks',
#   'Chevron',
#   '76',
#   'SUBWAY',
#   'Food 4 Less',
#   'Ralphs'],
#  ['ARCO',
#   'mcdonalds',
#   'starbucks',
#   'Jack in the Box',
#   '7-Eleven US',
#   'Chevron',
#   'In-N-Out Burger',
#   'walmart',
#   'Target',
#   '99 Cents Only Stores'],
#  ['Costco Wholesale Corp.',
#   'starbucks',
#   'mcdonalds',
#   'Target',
#   '7-Eleven US',
#   'Ralphs',
#   'ARCO',
#   'In-N-Out Burger',
#   'CVS',
#   'Chevron'],
#  ['Costco Wholesale Corp.',
#   'starbucks',
#   'mcdonalds',
#   'Target',
#   '7-Eleven US',
#   'ARCO',
#   'Jack in the Box',
#   'Ralphs',
#   'In-N-Out Burger',
#   'CVS'],
#  ['starbucks',
#   'mcdonalds',
#   'ARCO',
#   'Target',
#   'Chevron',
#   'In-N-Out Burger',
#   'Jack in the Box',
#   'Costco Wholesale Corp.',
#   '7-Eleven US',
#   'SUBWAY'],
#  ['starbucks',
#   'Target',
#   'Chevron',
#   'mcdonalds',
#   'In-N-Out Burger',
#   'Ralphs',
#   'Costco Wholesale Corp.',
#   'ARCO',
#   'SUBWAY',
#   'CVS'],
#  ['starbucks',
#   'mcdonalds',
#   'In-N-Out Burger',
#   'Target',
#   'ARCO',
#   'Chevron',
#   'Costco Wholesale Corp.',
#   '7-Eleven US',
#   'Ralphs',
#   'Jack in the Box'],
#  ['walmart',
#   'mcdonalds',
#   'Chevron',
#   'starbucks',
#   'Valero Energy',
#   'Taco Bell',
#   'Save Mart Supermarkets',
#   'ARCO',
#   'Dollar Tree',
#   "Carl's Jr."],
#  ['starbucks',
#   'Chevron',
#   'Target',
#   'Costco Wholesale Corp.',
#   'mcdonalds',
#   'In-N-Out Burger',
#   'ARCO',
#   'Del Taco',
#   'Tesla Motors',
#   'Jack in the Box'],
#  ['starbucks',
#   'Target',
#   'In-N-Out Burger',
#   'Del Taco',
#   'ARCO',
#   'Chevron',
#   "Carl's Jr.",
#   '7-Eleven US',
#   'Jack in the Box',
#   'Costco Wholesale Corp.'],
#  ['starbucks',
#   'mcdonalds',
#   'ARCO',
#   'Chevron',
#   'In-N-Out Burger',
#   'Target',
#   'Costco Wholesale Corp.',
#   'Jack in the Box',
#   'SUBWAY',
#   'walmart'],
#  ['ARCO',
#   'walmart',
#   'Jack in the Box',
#   'mcdonalds',
#   'Del Taco',
#   'Chevron',
#   'Dollar Tree',
#   "Carl's Jr.",
#   'starbucks',
#   'Stater Bros. Markets'],
#  ...]

# %% [markdown]
# ## 2.找出频繁项集
# 利用FP-Growth算法，构造FP-tree，从FP-tree中找到频繁项集。设置最小支持度为0.2
#
# 输出所有频繁项集，及其支持度。

# %%
frequent_itemsets = fpg.find_frequent_itemsets(dataSet, minimum_support=0.2*len(dataSet), include_support=True)
print(type(frequent_itemsets))   # print type

result = []
for itemset, support in frequent_itemsets:    # 将generator结果存入list
    result.append((itemset, support/len(dataSet)))

    
result_patterns = [i[0] for i in result]
result_support = [i[1] for i in result]
patterns_df = pd.DataFrame({"fluent_patterns":result_patterns,"support":result_support})
patterns = {}
for i in result :
    patterns[frozenset(sorted(i[0]))] = i[1]
patterns_df
# Out:
# <class 'generator'>
#                          fluent_patterns   support
# 0                            [mcdonalds]  0.948042
# 1                              [walmart]  0.754744
# 2                   [mcdonalds, walmart]  0.740714
# 3                               [SUBWAY]  0.481630
# 4                    [mcdonalds, SUBWAY]  0.474283
# 5                      [walmart, SUBWAY]  0.360681
# 6           [mcdonalds, walmart, SUBWAY]  0.358426
# 7                            [Shell Oil]  0.358114
# 8                 [mcdonalds, Shell Oil]  0.346091
# 9                   [walmart, Shell Oil]  0.303474
# 10       [mcdonalds, walmart, Shell Oil]  0.298459
# 11                      [Dollar General]  0.280245
# 12           [mcdonalds, Dollar General]  0.274151
# 13             [walmart, Dollar General]  0.272337
# 14  [mcdonalds, walmart, Dollar General]  0.267717
# 15                         [Chick-fil-A]  0.216071
# 16              [mcdonalds, Chick-fil-A]  0.211328
# 17                [walmart, Chick-fil-A]  0.205716
# 18     [mcdonalds, walmart, Chick-fil-A]  0.202565
# 19                             [Chevron]  0.215291
# 20                  [mcdonalds, Chevron]  0.201362
# 21                           [starbucks]  0.411780
# 22                [mcdonalds, starbucks]  0.393319
# 23                  [walmart, starbucks]  0.237545
# 24       [mcdonalds, walmart, starbucks]  0.233839
# 25                   [SUBWAY, starbucks]  0.204223
# 26                           [Walgreens]  0.231681
# 27                [mcdonalds, Walgreens]  0.226469
# 28                              [Target]  0.249146
# 29                   [mcdonalds, Target]  0.238505
# 30                         [7-Eleven US]  0.204692
# 31                      [Dunkin' Donuts]  0.237789
# 32           [mcdonalds, Dunkin' Donuts]  0.225885
# 33                                  [BP]  0.210382
# 34                       [mcdonalds, BP]  0.207392

# %% [markdown]
# ## 3.导出关联规则
# 从FP-tree和频繁项集中导出关联规则，并计算关联规则的置信度。

# %%
def generate_rules(patterns, min_confidence):
    patterns_group = group_patterns_by_length(patterns)
    raw_rules = defaultdict(set)
    for length, pattern_list in patterns_group.items():
        if length == 1:
            continue
        for pattern, support in pattern_list:
            item_list = list(pattern)
            for window_size in range(1, length):
                for i in range(0, length - window_size):
                    for j in range(i + window_size, length):
                        base_set = frozenset(item_list[i:j])
                        predict_set = frozenset(pattern - base_set)
                        confidence = support / patterns.get(base_set)
                        if confidence > min_confidence:
                            raw_rules[base_set].add((predict_set, confidence))

                        base_set, predict_set = predict_set, base_set
                        confidence = support / patterns.get(base_set)
                        if confidence > min_confidence:
                            raw_rules[base_set].add((predict_set, confidence))
    return raw_rules

def group_patterns_by_length(patterns):
    result = defaultdict(list)
    for pattern, support in patterns.items():
        result[len(pattern)].append((pattern, support))
    return result

def transform(raw_rules):
    result = list()
    for base_set, predict_set_list in raw_rules.items():
        for predict_set, confidence in predict_set_list:
            result.append((base_set, predict_set, confidence))
    
    return result

raw_rules = generate_rules(patterns, 0.7)
rules = transform(raw_rules)
rules.sort(key=lambda x: x[2], reverse=True)
rules_a = [i[0] for i in rules]
rules_b = [i[1] for i in rules]
confidence = [i[2] for i in rules]
rules_df = pd.DataFrame({"rules_a":rules_a,"rules_b":rules_b,"confidence":confidence})
rules_df
# Out:
#                         rules_a               rules_b  confidence
# 0             (SUBWAY, walmart)           (mcdonalds)    0.993748
# 1                          (BP)           (mcdonalds)    0.985789
# 2                      (SUBWAY)           (mcdonalds)    0.984744
# 3        (Chick-fil-A, walmart)           (mcdonalds)    0.984686
# 4          (starbucks, walmart)           (mcdonalds)    0.984399
# 5          (Shell Oil, walmart)           (mcdonalds)    0.983475
# 6     (Dollar General, walmart)           (mcdonalds)    0.983036
# 7                     (walmart)           (mcdonalds)    0.981411
# 8              (Dollar General)           (mcdonalds)    0.978254
# 9                 (Chick-fil-A)           (mcdonalds)    0.978045
# 10                  (Walgreens)           (mcdonalds)    0.977502
# 11  (mcdonalds, Dollar General)             (walmart)    0.976531
# 12             (Dollar General)             (walmart)    0.971782
# 13                  (Shell Oil)           (mcdonalds)    0.966427
# 14     (mcdonalds, Chick-fil-A)             (walmart)    0.958537
# 15                     (Target)           (mcdonalds)    0.957292
# 16             (Dollar General)  (mcdonalds, walmart)    0.955296
# 17                  (starbucks)           (mcdonalds)    0.955167
# 18                (Chick-fil-A)             (walmart)    0.952072
# 19             (Dunkin' Donuts)           (mcdonalds)    0.949941
# 20                (Chick-fil-A)  (mcdonalds, walmart)    0.937492
# 21                    (Chevron)           (mcdonalds)    0.935303
# 22       (mcdonalds, Shell Oil)             (walmart)    0.862371
# 23                  (Shell Oil)             (walmart)    0.847422
# 24                  (Shell Oil)  (mcdonalds, walmart)    0.833419
# 25                  (mcdonalds)             (walmart)    0.781310
# 26          (mcdonalds, SUBWAY)             (walmart)    0.755723
# 27                     (SUBWAY)             (walmart)    0.748875
# 28                     (SUBWAY)  (mcdonalds, walmart)    0.744193

# %% [markdown]
# ## 4.对关联规则进行评价
# 使用Lift和全置信度指标进行评价。

# %%
lift= []
fsupport = []

# 计算Lift
for index,row in rules_df.iterrows():
    temp = patterns[row["rules_a"]|row["rules_b"]] / patterns[row["rules_a"]] / patterns[row["rules_b"]] 
    lift.append(temp)
rules_df["lift"] = lift

# 计算kulc
for index,row in rules_df.iterrows():
    temp = patterns[row["rules_a"]|row["rules_b"]] / patterns[row["rules_b"]]
    fsupport.append( (row["confidence"]+temp)/2 )
rules_df["kulc"] = fsupport
rules_df

# %% [markdown]
# ## 5.可视化展示挖掘结果

# %%
fig,axes = plt.subplots(1,2,figsize=(20,5))
rules_df.plot(kind='hexbin',x="confidence",y="lift",C="kulc",gridsize=10,ax = axes[0],title='Picture 1: evaluation')

axes[1].bar([str(i) for i in patterns_df["fluent_patterns"]],patterns_df["support"])
axes[1].set_xticklabels([str(i) for i in patterns_df["fluent_patterns"]],rotation=90)
axes[1].set_xlabel("frequent item set")
axes[1].set_ylabel("support")
axes[1].set_title("Picture2: support of frequent item set")
plt.show()

# %% [markdown]
# Picture1展示了每个频繁规则的置信度、提升度、kulc。一般情况下，我们认为提升度大于3的关联规则是一个比较强的关联规则，当提升度为1时两者没有关联，但本数据集中关联规则的提升度大多在1-1.3，所以是比较弱的关联规则。
# Picture2展示了所有频繁项集的支持度，可见最受欢迎的品牌是麦当劳，紧随其后的是沃尔玛，同时去麦当劳和沃尔玛的人也很多。

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.barh([str(i)+"->"+str(j) for i,j in zip(rules_df["rules_a"],rules_df["rules_b"])], [i for i in rules_df["confidence"]], height=0.7, align='center', color='#AAAAAA')
# ax.set_yticklabels(rules_df["confidence"])      # 也可以在这里设置 条条 的标签~
ax.set_xlabel('confidence')
ax.set_ylabel('association rules')
ax.invert_yaxis()
ax.set_title('Picture3: confidence of association rules')

plt.show()

# %% [markdown]
# Picture3展示了所有的关联规则及其对应的置信度，从图中可以看出，所有关联规则的置信度都大于70%。尤其是第一条，去过SUBWAY和walmart的人几乎肯定会去mcdonalds。
